# %%
# %matplotlib inline
import GEOparse
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import decomposition
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LinearRegression
from sklearn.metrics import explained_variance_score, plot_roc_curve
from sklego.linear_model import LowessRegression
import statsmodels.api as sm
from scipy.stats import ttest_ind, skewtest, boxcox
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Reading in from external source

# %%
table = pd.read_csv("../Dataset/Fehlman2020/expression_matrix.csv", sep="\t")
#table = pd.read_csv("../Dataset/Wozniak2015/GSE64591_non-normalized.txt", sep="\t", header=5)

# %%
table
# Out:
#                miRNA  Healthy control 1  Healthy control 2  Healthy control 3  \
# 0      hsa-let-7a-3p           5.988790           7.380677           7.672810
# 1      hsa-let-7a-5p        2439.692620       20989.575296       31645.820205
# 2      hsa-let-7b-3p          11.780320          15.448649          13.338528
# 3      hsa-let-7b-5p        1040.209620       18504.673331        7955.195696
# 4      hsa-let-7c-3p                NaN           6.671031           6.848874
# ...              ...                ...                ...                ...
# 2544   hsa-miR-98-5p          20.964430          84.032030         159.892600
# 2545  hsa-miR-99a-3p           5.403362           5.327982           6.421957
# 2546  hsa-miR-99a-5p          13.697740         213.873700         184.569600
# 2547  hsa-miR-99b-3p           5.110449           5.773773           6.529618
# 2548  hsa-miR-99b-5p          11.077200         111.663100         197.377500
#
#       Healthy control 4  Healthy control 5  Healthy control 6  \
# 0              6.613076          11.527153           6.802500
# 1          39785.067842       31230.353897       38051.171659
# 2             13.885756          19.288142          15.084712
# 3          24977.608432       39978.077062       37595.019787
# 4              5.930795          10.633752           6.246456
# ...                 ...                ...                ...
# 2544         208.987800         125.215600         188.473300
# 2545           5.693892           8.883525           5.658731
# 2546          65.718150         140.656100         316.963400
# 2547           6.206826           8.768461           6.298098
# 2548          78.274060         103.701900         111.142000
#
#       Healthy control 7  Healthy control 8  Healthy control 9  ...  \
# 0              5.880256          11.543763           7.154083  ...
# 1            958.540489       26414.154148       16586.484823  ...
# 2              7.185237          16.824500          16.196026  ...
# 3           1359.028489        4014.889159       16931.607811  ...
# 4              5.475492           9.762535           7.198736  ...
# ...                 ...                ...                ...  ...
# 2544           7.963369         135.097300          70.247470  ...
# 2545           5.238846           9.544847           5.510658  ...
# 2546           8.551879         229.411500          83.380180  ...
# 2547           5.377624          11.095780           6.618033  ...
# 2548           8.635969         160.243100          68.589430  ...
#
#             OD 874        OD 875        OD 876        OD 877      OD 878  \
# 0         8.581974      6.405327      9.592039      8.458054    5.231669
# 1     31887.613521  10253.447955  68895.120418  26718.589860  124.858642
# 2        21.361416     12.543551     20.264019     14.556385    6.220702
# 3      4849.241869   1257.587019  10516.197060  10810.224198  479.614342
# 4         9.122395      6.682408     10.109299      7.948756    5.192131
# ...            ...           ...           ...           ...         ...
# 2544    155.673200     30.870220    315.734100    165.893100    5.210187
# 2545      7.606117      6.243903      9.437917      8.580856    4.516762
# 2546    176.617300     13.073290    126.437400     84.271230    6.452502
# 2547      8.079693      6.130816      8.947658      7.733689    5.346861
# 2548     67.373750     28.384700    138.880500     41.484160    6.308142
#
#             OD 879       OD 880        OD 881        OD 882        OD 883
# 0         9.144063     5.153392     11.459711     20.250156     15.120563
# 1     63857.761619   856.267323  27600.463068  19488.570664  22283.226524
# 2        24.859740     7.389210     18.877957     37.245982     22.464665
# 3      8749.304276  2202.739323   4600.033750   5339.333966   4008.972424
# 4         8.088978     4.853054     10.748838     19.576433     13.555511
# ...            ...          ...           ...           ...           ...
# 2544    494.706700     6.954913    138.359400    129.100000     97.391580
# 2545      7.153301     4.612040     10.001480     17.708110     13.154730
# 2546    176.668100     6.973993     64.588090    124.573200    180.569200
# 2547      7.124403     4.610744      9.381164     17.945740     12.749490
# 2548    136.889100     7.319033     67.766800    162.596200    160.133300
#
# [2549 rows x 3047 columns]

# %% [markdown]
# ### Get controls

# %%
sick = np.array(["LCa" in t for t in list(table)[1:]])
controls = 1 - sick

# %%
sum(sick)
# Out:
# 606

# %% [markdown]
# ### Drop NAN

# %%
table = table.fillna(table.iloc[:, 1:].min().min())

# %% [markdown]
# ### T-test

# %%
X = table.iloc[:, 1:].transpose()

# %%
X
# Out:
#                         0             1          2             3     \
# Healthy control 1   5.988790   2439.692620  11.780320   1040.209620
# Healthy control 2   7.380677  20989.575296  15.448649  18504.673331
# Healthy control 3   7.672810  31645.820205  13.338528   7955.195696
# Healthy control 4   6.613076  39785.067842  13.885756  24977.608432
# Healthy control 5  11.527153  31230.353897  19.288142  39978.077062
# ...                      ...           ...        ...           ...
# OD 879              9.144063  63857.761619  24.859740   8749.304276
# OD 880              5.153392    856.267323   7.389210   2202.739323
# OD 881             11.459711  27600.463068  18.877957   4600.033750
# OD 882             20.250156  19488.570664  37.245982   5339.333966
# OD 883             15.120563  22283.226524  22.464665   4008.972424
#
#                         4            5          6             7          8     \
# Healthy control 1   3.450000   194.282820   7.189860    766.731620   5.351587
# Healthy control 2   6.671031  3965.491812  14.408822   5312.466200   6.295542
# Healthy control 3   6.848874  2217.527520  20.839338   7063.847958   6.827632
# Healthy control 4   5.930795  5927.803928   8.536264  11272.834600   6.348113
# Healthy control 5  10.633752  9297.550922  17.881494   8031.057737  10.243077
# ...                      ...          ...        ...           ...        ...
# OD 879              8.088978  2909.559981  28.578137  20097.402512   7.490324
# OD 880              4.853054   250.299623   5.376270    269.119423   4.968522
# OD 881             10.748838   894.023748  19.264314   7342.882355   9.876033
# OD 882             19.576433  1166.722235  26.898383   4405.036611  17.743496
# OD 883             13.555511   626.328078  27.210473   5546.123823  13.147709
#
#                         9     ...       2539       2540       2541  \
# Healthy control 1   8.520220  ...   3.450000   3.450000   4.746277
# Healthy control 2  21.514407  ...   6.811566   5.140207   5.220955
# Healthy control 3  25.900714  ...   6.660123   5.649686   5.990099
# Healthy control 4  28.759241  ...   6.057018   5.279675   5.307264
# Healthy control 5  28.621188  ...  10.464910   8.716137   8.611114
# ...                      ...  ...        ...        ...        ...
# OD 879             48.978989  ...   7.674804   6.483046   6.951983
# OD 880              5.996783  ...   4.629021   4.099097   4.096209
# OD 881             20.532105  ...  10.152630   8.744794   9.087831
# OD 882             44.263706  ...  18.804670  16.990830  16.587790
# OD 883             50.319452  ...  13.900020  12.273350  12.477010
#
#                          2542       2543        2544       2545        2546  \
# Healthy control 1    60.57162   3.450000   20.964430   5.403362   13.697740
# Healthy control 2   191.81740  10.330540   84.032030   5.327982  213.873700
# Healthy control 3   417.67460   9.777365  159.892600   6.421957  184.569600
# Healthy control 4  1573.82700   9.383300  208.987800   5.693892   65.718150
# Healthy control 5   452.85390  16.214390  125.215600   8.883525  140.656100
# ...                       ...        ...         ...        ...         ...
# OD 879             2131.15500  17.118230  494.706700   7.153301  176.668100
# OD 880               12.14961   7.255633    6.954913   4.612040    6.973993
# OD 881             1274.89100  14.430910  138.359400  10.001480   64.588090
# OD 882              938.91320  32.776040  129.100000  17.708110  124.573200
# OD 883              537.14860  18.742700   97.391580  13.154730  180.569200
#
#                         2547        2548
# Healthy control 1   5.110449   11.077200
# Healthy control 2   5.773773  111.663100
# Healthy control 3   6.529618  197.377500
# Healthy control 4   6.206826   78.274060
# Healthy control 5   8.768461  103.701900
# ...                      ...         ...
# OD 879              7.124403  136.889100
# OD 880              4.610744    7.319033
# OD 881              9.381164   67.766800
# OD 882             17.945740  162.596200
# OD 883             12.749490  160.133300
#
# [3046 rows x 2549 columns]

# %%
X_healthy, X_cancer = X[controls == 1], X[sick == 1]

# %%
results = ttest_ind(X_healthy, X_cancer).pvalue

# %%
lowest, pvalues = np.argsort(results)[:5], np.sort(results)[:5]

# %%
table.iloc[lowest, 0], pvalues
# Out:
# (143     hsa-miR-1273g-3p
#  343       hsa-miR-197-3p
#  808      hsa-miR-374c-5p
#  806      hsa-miR-374b-5p
#  1753        hsa-miR-5684
#  Name: miRNA, dtype: object,
#  array([3.57301555e-56, 1.00274365e-41, 2.17979603e-39, 2.24938929e-39,
#         6.76578479e-39]))

# %% [markdown]
# ### F-test

# %%
t3 = table.iloc[:, 1:].transpose()

# %%
f, p = f_classif(t3, sick)

# %% [markdown]
# ### ANOVA

# %%
t3
# Out:
#                         0             1          2             3     \
# Healthy control 1   5.988790   2439.692620  11.780320   1040.209620
# Healthy control 2   7.380677  20989.575296  15.448649  18504.673331
# Healthy control 3   7.672810  31645.820205  13.338528   7955.195696
# Healthy control 4   6.613076  39785.067842  13.885756  24977.608432
# Healthy control 5  11.527153  31230.353897  19.288142  39978.077062
# ...                      ...           ...        ...           ...
# OD 879              9.144063  63857.761619  24.859740   8749.304276
# OD 880              5.153392    856.267323   7.389210   2202.739323
# OD 881             11.459711  27600.463068  18.877957   4600.033750
# OD 882             20.250156  19488.570664  37.245982   5339.333966
# OD 883             15.120563  22283.226524  22.464665   4008.972424
#
#                         4            5          6             7          8     \
# Healthy control 1   3.450000   194.282820   7.189860    766.731620   5.351587
# Healthy control 2   6.671031  3965.491812  14.408822   5312.466200   6.295542
# Healthy control 3   6.848874  2217.527520  20.839338   7063.847958   6.827632
# Healthy control 4   5.930795  5927.803928   8.536264  11272.834600   6.348113
# Healthy control 5  10.633752  9297.550922  17.881494   8031.057737  10.243077
# ...                      ...          ...        ...           ...        ...
# OD 879              8.088978  2909.559981  28.578137  20097.402512   7.490324
# OD 880              4.853054   250.299623   5.376270    269.119423   4.968522
# OD 881             10.748838   894.023748  19.264314   7342.882355   9.876033
# OD 882             19.576433  1166.722235  26.898383   4405.036611  17.743496
# OD 883             13.555511   626.328078  27.210473   5546.123823  13.147709
#
#                         9     ...       2539       2540       2541  \
# Healthy control 1   8.520220  ...   3.450000   3.450000   4.746277
# Healthy control 2  21.514407  ...   6.811566   5.140207   5.220955
# Healthy control 3  25.900714  ...   6.660123   5.649686   5.990099
# Healthy control 4  28.759241  ...   6.057018   5.279675   5.307264
# Healthy control 5  28.621188  ...  10.464910   8.716137   8.611114
# ...                      ...  ...        ...        ...        ...
# OD 879             48.978989  ...   7.674804   6.483046   6.951983
# OD 880              5.996783  ...   4.629021   4.099097   4.096209
# OD 881             20.532105  ...  10.152630   8.744794   9.087831
# OD 882             44.263706  ...  18.804670  16.990830  16.587790
# OD 883             50.319452  ...  13.900020  12.273350  12.477010
#
#                          2542       2543        2544       2545        2546  \
# Healthy control 1    60.57162   3.450000   20.964430   5.403362   13.697740
# Healthy control 2   191.81740  10.330540   84.032030   5.327982  213.873700
# Healthy control 3   417.67460   9.777365  159.892600   6.421957  184.569600
# Healthy control 4  1573.82700   9.383300  208.987800   5.693892   65.718150
# Healthy control 5   452.85390  16.214390  125.215600   8.883525  140.656100
# ...                       ...        ...         ...        ...         ...
# OD 879             2131.15500  17.118230  494.706700   7.153301  176.668100
# OD 880               12.14961   7.255633    6.954913   4.612040    6.973993
# OD 881             1274.89100  14.430910  138.359400  10.001480   64.588090
# OD 882              938.91320  32.776040  129.100000  17.708110  124.573200
# OD 883              537.14860  18.742700   97.391580  13.154730  180.569200
#
#                         2547        2548
# Healthy control 1   5.110449   11.077200
# Healthy control 2   5.773773  111.663100
# Healthy control 3   6.529618  197.377500
# Healthy control 4   6.206826   78.274060
# Healthy control 5   8.768461  103.701900
# ...                      ...         ...
# OD 879              7.124403  136.889100
# OD 880              4.610744    7.319033
# OD 881              9.381164   67.766800
# OD 882             17.945740  162.596200
# OD 883             12.749490  160.133300
#
# [3046 rows x 2549 columns]

# %%
X = np.array(sick).reshape(-1, 1)

# %%
linreg = LinearRegression()
linreg.fit(X, t3)
# Out:
# LinearRegression()

# %%
fitted = linreg.predict(X)
explained_variance_score(t3, fitted)
# Out:
# 0.003419774837530661

# %% [markdown]
# ### Mean-variance-plot

# %%
mirnas = table.iloc[:, 0]
table = table.iloc[:, 1:]

# %%
table = table.transpose()

# %%
np.mean(table)
# Out:
# 0           9.081349
# 1       22968.943128
# 2          18.962880
# 3       14366.212882
# 4           8.231085
#             ...
# 2544      123.431074
# 2545        7.839207
# 2546       80.060869
# 2547        8.341195
# 2548       70.713978
# Length: 2549, dtype: float64

# %%
def get_means_and_variances(table):
    return np.mean(table), np.var(table, ddof=1)

# %%
def mean_variance_plot(table):
    means, variances = get_means_and_variances(table)
    plt.scatter(means, variances)
    plt.xlabel("mean")
    plt.ylabel("variance")
    plt.plot()

# %%
mean_variance_plot(table)

# %%
log_table = np.log2(table)

# %%
mean_variance_plot(log_table.loc[:, np.mean(log_table) < 3.5])

# %%
mask = np.mean(log_table) > 3.2
mirnas = mirnas[mask]
log_table = log_table.loc[:, mask]

# %% [markdown]
# ### Loess regression

# %%
lowess = LowessRegression(sigma=1, span=0.1)

# %%
means, variances = get_means_and_variances(log_table)
lowess.fit(means.to_numpy().reshape(-1,1), variances)
# Out:
# LowessRegression(span=0.1)

# %%
x_axis = np.linspace(-2, 14, 100)
y_axis = lowess.predict(x_axis.reshape(-1,1))

# %%
plt.scatter(means, variances, color="b")
plt.scatter(x_axis, y_axis, color="y")
plt.xlabel("mean")
plt.ylabel("variance")
plt.legend(["Sample points", "Lowess regression"])
plt.plot()
# Out:
# []

# %% [markdown]
# ### Lowess normalization

# %%
adj_var = lowess.predict(means.to_numpy().reshape(-1, 1))

# %%
log_table /= np.sqrt(adj_var)

# %%
mean_variance_plot(log_table)

# %%
norm_log_table = log_table - np.mean(log_table)
norm_log_table /= np.sqrt(np.mean(np.var(norm_log_table, ddof=1)))
mean_variance_plot(norm_log_table)

# %%
norm_log_table = log_table - np.mean(log_table)

# %%
norm_log_table /= np.mean(np.std(norm_log_table))

# %%
mean_variance_plot(norm_log_table)

# %% [markdown]
# ### PCA

# %%
pca = decomposition.PCA(n_components=10)

# %%
pca.fit(norm_log_table)
# Out:
# PCA(n_components=10)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.61163438, 0.1065524 , 0.06283626, 0.04344915, 0.02479152,
#        0.01729498, 0.01221988, 0.01139373, 0.00934711, 0.00732812])

# %%
components = pca.transform(norm_log_table)

# %%
components
# Out:
# array([[ 4.79573800e+01, -4.17401300e+00,  3.42596433e+00, ...,
#          8.55769727e-01, -2.75161118e-01,  1.41074698e+00],
#        [-8.58982449e+00, -6.59604164e+00, -6.13927188e+00, ...,
#          8.01989116e-03, -1.45087439e+00,  1.95187856e+00],
#        [-5.42921706e+00, -1.14464166e+01, -5.48454818e+00, ...,
#          1.06727787e+00,  2.68528422e+00, -2.56461704e+00],
#        ...,
#        [-6.19669408e+00, -6.26365034e+00,  2.10651930e+00, ...,
#         -4.49294671e-01,  5.54622483e+00, -1.33393494e+00],
#        [-2.78785187e+01, -9.85264645e-01,  1.49213067e+01, ...,
#          1.61464813e+00,  3.66020155e+00,  9.52706745e-02],
#        [-1.07452164e+01, -9.81522863e+00,  5.87709469e+00, ...,
#          2.70033988e+00,  2.50669001e+00,  1.01512122e+00]])

# %%
sum(controls)
# Out:
# 2440

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Cancer', 'Healthy']
colors = ['r', 'g']
ax.scatter(components[controls == False, 0], components[controls == False, 1], c = 'r', s = 10)
ax.scatter(components[controls == True, 0], components[controls == True, 1], c = 'g', s = 10)
ax.legend(targets)
ax.grid()

# %%
components2 = components[components[:,0] < 20, :]
controls2 = controls[components[:,0] < 20]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Cancer', 'Healthy']
colors = ['r', 'g']
ax.scatter(components2[controls2 == False, 0], components2[controls2 == False, 1], c = 'r', s = 10)
ax.scatter(components2[controls2 == True, 0], components2[controls2 == True, 1], c = 'g', s = 10)
ax.legend(targets)
ax.grid()

# %% [markdown]
# ### XGBoost

# %%
X_train, X_test, y_train, y_test = train_test_split(norm_log_table, controls, test_size=0.33, random_state=42)

# %%
model = XGBClassifier(use_label_encoder=False)
model.fit(X_train, y_train)
# Out:
# [18:08:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=16,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
plot_roc_curve(model, X_test, y_test)
# Out:
# C:\Users\olefr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### Exporting data

# %%
from Scripts import converters

# %%
sequences = converters.canonical_to_seq(mirnas)

# %%
norm_log_table.columns = sequences
norm_log_table["cancer"] = sick
norm_log_table.head()
# Out:
#                    UGAGGUAGUAGGUUGUAUAGUU  CUAUACAACCUACUGCCUUCCC  \
# Healthy control 1               -1.259045               -0.571416
# Healthy control 2                0.319587               -0.167046
# Healthy control 3                0.620753               -0.386115
# Healthy control 4                0.788644               -0.326141
# Healthy control 5                0.611059                0.164051
#
#                    UGAGGUAGUAGGUUGUGUGGUU  UGAGGUAGUAGGUUGUAUGGUU  \
# Healthy control 1               -1.595965               -1.561622
# Healthy control 2                0.596758                0.554326
# Healthy control 3               -0.046295                0.146555
# Healthy control 4                0.825244                0.836369
# Healthy control 5                1.183526                1.152138
#
#                    CUAUACGACCUGCUGCCUUUCU  AGAGGUAGUAGGUUGCAUAGUU  \
# Healthy control 1               -1.088198               -1.113114
# Healthy control 2                0.045184                0.259128
# Healthy control 3                0.646794                0.461123
# Healthy control 4               -0.808342                0.792478
# Healthy control 5                0.397223                0.552097
#
#                    UGAGGUAGGAGGUUGUAUAGUU  CUAUACAAUCUAUUGCCUUCCC  \
# Healthy control 1               -1.227454               -0.464471
# Healthy control 2               -0.081398               -0.240628
# Healthy control 3                0.148174               -0.243878
# Healthy control 4                0.277701               -0.551566
# Healthy control 5                0.271748                0.131831
#
#                    UGAGGUAGUAGAUUGUAUAGUU  UGAGGUAGUAGUUUGUACAGUU  ...  \
# Healthy control 1               -1.162913               -1.047377  ...
# Healthy control 2                0.323827                0.107445  ...
# Healthy control 3                0.661761                0.453063  ...
# Healthy control 4                1.005166                1.128938  ...
# Healthy control 5                0.580284                0.255503  ...
#
#                    UGGGGAGCUGAGGCUCUGGGGGUG  AAGGCAGGGCCCCCGCUCCCC  \
# Healthy control 1                 -0.835058              -0.946123
# Healthy control 2                 -0.013119               0.204821
# Healthy control 3                  0.020705               0.114733
# Healthy control 4                  0.635271              -0.140005
# Healthy control 5                  0.845758               0.219520
#
#                    CACAUGGCCGAAACAGAGAAGU  UCUUCUCUGUUUUGGCCAUGUG  \
# Healthy control 1               -2.392618               -1.528878
# Healthy control 2                1.987898                0.960193
# Healthy control 3                1.858523                1.353754
# Healthy control 4                0.492133                0.201620
# Healthy control 5                1.577019                0.893980
#
#                    UUUGGCACUAGCACAUUUUUGCU  CUAUACAACUUACUACUUUCCC  \
# Healthy control 1                -1.037971               -2.158187
# Healthy control 2                -0.140807               -0.226327
# Healthy control 3                 0.464836               -0.323269
# Healthy control 4                 1.497305               -0.395733
# Healthy control 5                 0.527775                0.567735
#
#                    UGAGGUAGUAAGUUGUAUUGUU  AACCCGUAGAUCCGAUCUUGUG  \
# Healthy control 1               -1.159749               -1.308915
# Healthy control 2                0.163802                1.396140
# Healthy control 3                0.777073                1.251092
# Healthy control 4                1.032345                0.234636
# Healthy control 5                0.544021                0.983645
#
#                    CACCCGUAGAACCGACCUUGCG  cancer
# Healthy control 1               -1.487132   False
# Healthy control 2                0.783774   False
# Healthy control 3                1.343621   False
# Healthy control 4                0.434607   False
# Healthy control 5                0.711079   False
#
# [5 rows x 690 columns]

# %%
norm_log_table.to_csv("../TransformedData/Fehlmann2020.csv", index=False)
