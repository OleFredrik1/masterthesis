# %%
# %matplotlib inline
import GEOparse
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import decomposition
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import explained_variance_score, plot_roc_curve
import statsmodels.api as sm
from scipy.stats import ttest_ind
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklego.linear_model import LowessRegression

# %% [markdown]
# ### Reading in from external source

# %%
geo = "GSE24709"
data = GEOparse.get_GEO(geo=geo, destdir="../Dataset/Leidinger2011", silent=True)
#table = pd.read_csv("../Dataset/Fehlman2020/expression_matrix.csv", sep="\t")
#table = pd.read_csv("../Dataset/Wozniak2015/GSE64591_non-normalized.txt", sep="\t", header=5)

# %%
table = pd.concat((val.table.iloc[:,1:] for val in data.gsms.values()), axis=1).transpose()
mirnas = list(data.gsms.values())[0].table.iloc[:,0]

# %%
table
# Out:
#                0            1            2           3          4    \
# VALUE   903.359155   760.950704   674.176056  367.605634  16.507042
# VALUE  1329.408451   528.338028  1182.584507  218.338028  14.873239
# VALUE  3887.415493  1040.383803   458.901409   25.521127  25.521127
# VALUE  1860.767606   305.915493  1026.197183  123.950704   3.154930
# VALUE  2321.352113   308.788732  1470.084507  215.098591  19.943662
# ...            ...          ...          ...         ...        ...
# VALUE  1054.570423   163.718310  4077.718310  155.042253  36.225352
# VALUE  1932.366197   156.788732  3362.823944  114.084507   1.000000
# VALUE   782.478873   258.140845  2645.704225  166.929577  21.633803
# VALUE   408.788732   181.859155   539.661972   92.338028   1.000000
# VALUE   925.390845   265.295775  2001.605634  143.718310  90.647887
#
#              5           6          7           8           9    ...  \
# VALUE  47.352113  101.070423   1.000000    1.000000   87.690141  ...
# VALUE  14.873239  126.816901  14.873239   14.873239   79.887324  ...
# VALUE  25.521127  227.661972  25.521127   78.873239  113.352113  ...
# VALUE  46.422535  146.338028  14.478873   14.478873    3.154930  ...
# VALUE  26.366197  120.507042  14.478873    1.000000    6.647887  ...
# ...          ...         ...        ...         ...         ...  ...
# VALUE  36.225352  141.690141  15.211268   49.380282   66.140845  ...
# VALUE   1.000000  380.309859   1.000000   35.690141    1.000000  ...
# VALUE  59.915493  272.056338  59.915493   21.633803   36.535211  ...
# VALUE  12.281690  163.098591  17.183099    1.000000    1.000000  ...
# VALUE  43.380282  334.394366  19.211268  125.633803    3.154930  ...
#
#                853         854          855         856         857  \
# VALUE  3982.566901  123.380282  5567.345070  187.267606  116.845070
# VALUE  3708.204225   79.887324  5079.535211  180.112676   79.887324
# VALUE  7269.838028   25.521127   358.478873  325.521127  212.676056
# VALUE  4284.021127  104.422535  8404.859155  198.591549   84.760563
# VALUE  2645.704225   80.394366  8897.661972  208.535211  107.211268
# ...            ...         ...          ...         ...         ...
# VALUE  1780.633803  516.056338  3548.352113    1.000000   20.845070
# VALUE  3548.352113  185.577465  2526.619718   89.211268   70.478873
# VALUE  3079.133803  166.929577  4460.126761  111.549296   89.070423
# VALUE  4284.021127  200.732394  2969.676056  194.338028  148.197183
# VALUE  3887.415493  199.098591  5079.535211   68.788732   43.380282
#
#               858         859         860         861         862
# VALUE   78.985915   32.816901   60.760563  159.380282  227.661972
# VALUE  112.676056   79.887324   62.253521   14.873239  278.140845
# VALUE  125.746479   25.521127  113.352113   25.521127  286.873239
# VALUE   58.450704   84.760563    3.154930  152.985916  161.746479
# VALUE   55.887324   49.577465   55.887324  156.788732  202.873239
# ...           ...         ...         ...         ...         ...
# VALUE   80.478873   86.929577   27.267606  360.169014  323.239437
# VALUE   89.211268  128.901409   61.014085  232.985916  170.929577
# VALUE  100.507042  124.957746   74.366197  400.619718  229.690141
# VALUE  120.394366  148.197183   92.338028  506.704225  283.915493
# VALUE   90.647887  143.718310   90.647887  360.169014  360.169014
#
# [71 rows x 863 columns]

# %% [markdown]
# ### Seperate case and controls

# %%
meta = np.array([k.metadata["title"][0] for k in list(data.gsms.values())])

# %%
list(data.gsms.values())[40].metadata
# Out:
# {'title': ['lung cancer 15'],
#  'geo_accession': ['GSM608824'],
#  'status': ['Public on Mar 11 2011'],
#  'submission_date': ['Oct 14 2010'],
#  'last_update_date': ['Mar 11 2011'],
#  'type': ['RNA'],
#  'channel_count': ['1'],
#  'source_name_ch1': ['RNA from blood'],
#  'organism_ch1': ['Homo sapiens'],
#  'taxid_ch1': ['9606'],
#  'characteristics_ch1': ['disease state: lung cancer'],
#  'treatment_protocol_ch1': ['stored at -20 degree'],
#  'molecule_ch1': ['total RNA'],
#  'extract_protocol_ch1': ['Blood of patients and volunteers without known disease was extracted in PAXgene Blood RNA tubes (BD, Franklin Lakes, New Jersey USA). For each blood donor, 5 ml of peripheral blood were obtained. The content of blood sampling tubes of each patient and healthy donor was centrifuged at 5000 g for 10 min at room temperature. The supernatant was discarded while the pellet was resuspended in 10 ml RNase free water by vortex. The suspension is again centrifuged at 5000 g for 10 min at RT. Subsequently, the total RNA including the miRNA was isolated using the miRNeasy kit (Qiagen GmbH, Hilden). Therefore the pellet was resuspended in 700 Î¼l QIAzol lysis reagent and incubated for 5 min at RT. Then, 140 Î¼l chloroform were added, vortexed for 15 sec, and incubated for 2-3 min at RT. This was followed by a centrifugation at 14000 rpm and 4Â°C for 15 min. The upper, watery phase was removed and 1,5 times of its volume added in 100% ethanol (ca. 900 Î¼l). Each 700 Î¼l of this mixture were placed on a column and centrifuged at 13000 rpm at RT for 15 sec. After the mixture had completely passed the column, 700 Î¼l of Buffer RWT were added to each column, and again centrifuged at 13000 rpm at RT for 15 sec. Following this, 500 Î¼l Buffer RPL were added to the column and centrifuged at 13000 rpm at RT for 15 sec. After this, another 500 Î¼l Buffer RPL were added to the column and centrifuged at 13000 rpm at RT for 2 min. The column was then centrifuged at 13000 rpm and RT for 1 min to dry it. The following was the elution step with 40 Î¼l RNase free water, centrifuging at 13000 rpm at RT for 1 min. The eluted RNA was stored at -70Â°C.'],
#  'label_ch1': ['biotin'],
#  'label_protocol_ch1': ['MPEA, microfluidic primer extension assay Biotin labeling'],
#  'hyb_protocol': ['according to manufacturers instruction (febit biomed)'],
#  'scan_protocol': ['Wizard software on standard Microsoft Windows Workstation PC'],
#  'data_processing': ['summarizing of technical replica by median and quantile normalization. Following BG correction, negative values were corrected to 1'],
#  'platform_id': ['GPL9040'],
#  'contact_name': ['Andreas,,Keller'],
#  'contact_institute': ['Saarland University'],
#  'contact_address': ['Building 60'],
#  'contact_city': ['Homburg'],
#  'contact_zip/postal_code': ['69112'],
#  'contact_country': ['Germany'],
#  'supplementary_file': ['NONE'],
#  'series_id': ['GSE24709'],
#  'data_row_count': ['863']}

# %%
sick = np.array(["lung" in k.metadata["title"][0] for k in list(data.gsms.values())])
controls = np.array(["normal" in k.metadata["title"][0] for k in list(data.gsms.values())])
mask = sick + controls
table = table.loc[mask]
sick = sick[mask]
controls = controls[mask]
meta = meta[mask]

# %%
sum(controls)
# Out:
# 19

# %% [markdown]
# ### Drop NAN

# %%
table = table.dropna(1)
# Out:
# C:\Users\olefr\AppData\Local\Temp/ipykernel_17372/1927661217.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   table = table.dropna(1)

# %% [markdown]
# ### T-test

# %%
X = table

# %%
X
# Out:
#                0           1             2           3           4    \
# VALUE  2321.352113  308.788732   1470.084507  215.098591   19.943662
# VALUE   754.295775  196.845070   2735.049296  104.225352   26.985915
# VALUE   717.450704  140.732394   3797.809859   86.535211    6.647887
# VALUE  1932.366197  165.633803   2645.704225  105.408451   46.422535
# VALUE  1494.492958   99.380282   4619.711268   73.464789    3.323944
# VALUE  1006.838028  174.929577   2321.352113   66.760563   31.042254
# VALUE   782.478873  260.619718   3362.823944  281.521127   77.690141
# VALUE  1518.901408  301.549296   4077.718310  395.915493    5.126761
# VALUE  1230.028169  224.394366   4284.021127  447.605634  170.647887
# VALUE  1244.859155  244.478873   2845.943662  342.309859   87.577465
# VALUE  1601.609155  331.352113   3548.352113  269.690141   64.225352
# VALUE  1215.197183  447.605634   3708.204225  294.873239  119.605634
# VALUE   893.500000  370.281690   1860.767606  317.577465   33.521127
# VALUE  1134.880282  279.070423   3362.823944  489.267606   23.380282
# VALUE   981.626761  411.126761   1780.633803  253.183099   42.704225
# VALUE   994.232394  385.070423   1134.880282  465.971831   97.183099
# VALUE   903.359155  281.521127   2060.943662  249.746479   38.929577
# VALUE   499.661972  124.957746   2220.816901  377.915493   76.619718
# VALUE  2321.352113  123.661972   3548.352113   58.253521   86.028169
# VALUE  1470.084507  314.704225   3362.823944  469.690141    2.309859
# VALUE   267.239437  125.633803  10210.683100  170.929577   27.042254
# VALUE   176.535211  215.436620   1697.169014   55.070423    1.000000
# VALUE   171.267606  405.774648    649.366197  122.929577   21.915493
# VALUE  2526.619718   92.000000   8404.859155  141.859155   39.154930
# VALUE  1278.000000  254.197183   2735.049296   92.000000   18.901408
# VALUE  1417.514085  155.774648   7975.436620   79.887324   24.732394
# VALUE   644.183099  160.957747   1518.901408  125.971831   63.267606
# VALUE  1198.890845  395.915493   2645.704225   68.788732   38.281690
# VALUE   402.760563  722.640845    573.859155  280.000000   86.929577
# VALUE   423.605634  316.140845    835.056338  254.535211   55.070423
# VALUE   74.478873    8.478873    1.000000  250.478873   51.380282
# VALUE   80.845070  115.211268   18.901408  215.098591  451.577465
# VALUE   21.859155   52.507042   11.830986   89.323944   81.802817
# VALUE   72.873239  106.309859   19.070423  228.957747  180.366197
# VALUE   81.239437  120.394366  159.380282  105.859155  268.000000
# VALUE   68.338028  175.154930    1.000000   86.929577  101.211268
# VALUE  106.084507  126.422535   27.577465  175.633803  244.478873
# VALUE    1.000000  120.873239    1.000000  100.619718  214.732394
# VALUE   56.000000   84.366197   34.873239  129.295775  203.605634
# VALUE   66.197183   19.323944   66.197183  237.577465  152.028169
# VALUE   23.577465   23.577465   64.732394  212.056338  146.732394
# VALUE   17.183099   63.436620   47.746479  221.521127   74.957746
# VALUE   44.169014    1.000000   24.788732  221.521127   74.957746
# VALUE   60.901408    1.000000   60.901408  274.253521  100.788732
# VALUE   38.084507   25.211268   15.436620  200.281690  102.957746
# VALUE    6.253521  105.521127   40.676056  154.253521  193.014084
# VALUE   68.112676   76.732394   37.183099  193.690141  208.901409
# VALUE  166.309859  152.788732   84.760563  243.774648  243.774648
# VALUE   67.943662  101.633803   58.309859  166.929577  166.929577
# VALUE   80.478873   86.929577   27.267606  360.169014  323.239437
# VALUE   89.211268  128.901409   61.014085  232.985916  170.929577
# VALUE  100.507042  124.957746   74.366197  400.619718  229.690141
# VALUE  120.394366  148.197183   92.338028  506.704225  283.915493
# VALUE   90.647887  143.718310   90.647887  360.169014  360.169014
#
# [47 rows x 863 columns]

# %%
X_healthy, X_cancer = X[controls == 1], X[sick == 1]

# %%
results = ttest_ind(X_healthy, X_cancer).pvalue

# %%
lowest, pvalues = np.argsort(results)[:5], np.sort(results)[:5]

# %%
mirnas.iloc[lowest], pvalues
# Out:
# (512     hsa-miR-20b
#  813    hsa-miR-106a
#  20       hsa-miR-17
#  251     hsa-miR-20a
#  47      hsa-let-7d*
#  Name: ID_REF, dtype: object,
#  array([6.65446684e-09, 3.41690525e-08, 1.02838436e-07, 7.73639519e-07,
#         1.15497101e-06]))

# %% [markdown]
# ### F-test

# %%
t3 = table

# %%
f, p = f_classif(t3, sick)

# %%
np.mean(p)
# Out:
# 0.27416953752268947

# %% [markdown]
# ### ANOVA

# %%
t3
# Out:
#                0           1             2           3           4    \
# VALUE  2321.352113  308.788732   1470.084507  215.098591   19.943662
# VALUE   754.295775  196.845070   2735.049296  104.225352   26.985915
# VALUE   717.450704  140.732394   3797.809859   86.535211    6.647887
# VALUE  1932.366197  165.633803   2645.704225  105.408451   46.422535
# VALUE  1494.492958   99.380282   4619.711268   73.464789    3.323944
# VALUE  1006.838028  174.929577   2321.352113   66.760563   31.042254
# VALUE   782.478873  260.619718   3362.823944  281.521127   77.690141
# VALUE  1518.901408  301.549296   4077.718310  395.915493    5.126761
# VALUE  1230.028169  224.394366   4284.021127  447.605634  170.647887
# VALUE  1244.859155  244.478873   2845.943662  342.309859   87.577465
# VALUE  1601.609155  331.352113   3548.352113  269.690141   64.225352
# 0.0728019007331208

# %% [markdown]
# ### Mean-variance-plot

# %%
np.mean(table)
# Out:
# 0      1135.465838
# 1       260.165268
# 2      2699.559934
# 3       205.768804
# 4        41.683848
#           ...
# 858      63.918190
# 859      84.510039
# 860      46.737189
# 861     189.684147
# 862     190.850464
# Length: 863, dtype: float64

# %%
def get_means_and_variances(table):
    return np.mean(table), np.var(table, ddof=1)

# %%
def mean_variance_plot(table):
    means, variances = get_means_and_variances(table)
    plt.scatter(means, variances)
    plt.xlabel("mean")
    plt.ylabel("variance")
    plt.plot()

# %%
mean_variance_plot(table)

# %% [markdown]
# ### Log transformation

# %%
log_table = np.log2(table)

# %%
mean_variance_plot(log_table)

# %% [markdown]
# ### Loess regression

# %%
lowess = LowessRegression(sigma=1, span=0.1)

# %%
means, variances = get_means_and_variances(log_table)
lowess.fit(means.to_numpy().reshape(-1,1), variances)
# Out:
# LowessRegression(span=0.1)

# %%
x_axis = np.linspace(-2, 14, 100)
y_axis = lowess.predict(x_axis.reshape(-1,1))

# %%
plt.scatter(means, variances, color="b")
plt.scatter(x_axis, y_axis, color="y")
plt.xlabel("mean")
plt.ylabel("variances")
plt.legend(["Sample points", "Lowess regression"])
plt.plot()
# Out:
# []

# %% [markdown]
# ### Lowess normalization

# %%
adj_var = lowess.predict(means.to_numpy().reshape(-1, 1))

# %%
log_table /= np.sqrt(adj_var)

# %%
mean_variance_plot(log_table)

# %% [markdown]
# ### Remove mean

# %%
norm_log_table = log_table - np.mean(log_table)

# %%
norm_log_table /= np.sqrt(np.mean(np.var(norm_log_table, ddof=1)))

# %%
mean_variance_plot(norm_log_table)

# %% [markdown]
# ### PCA

# %%
pca = decomposition.PCA(n_components=10)

# %%
pca.fit(norm_log_table)
# Out:
# PCA(n_components=10)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.20598118, 0.06937448, 0.063194  , 0.05439155, 0.05081948,
#        0.03598599, 0.03388222, 0.03136279, 0.02860487, 0.02718607])

# %%
components = pca.transform(norm_log_table)

# %%
components.shape
# Out:
# (47, 10)

# %%
sum(controls)
# Out:
# 19

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Cancer', 'Healthy']
colors = ['r', 'g']
ax.scatter(components[controls == False, 0], components[controls == False, 1], c = 'r', s = 10)
ax.scatter(components[controls == True, 0], components[controls == True, 1], c = 'g', s = 10)
ax.legend(targets)
ax.grid()

# %%
components2 = components[components[:,0] < 20, :]
controls2 = controls[components[:,0] < 20]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Cancer', 'Healthy']
colors = ['r', 'g']
ax.scatter(components2[controls2 == False, 0], components2[controls2 == False, 1], c = 'r', s = 10)
ax.scatter(components2[controls2 == True, 0], components2[controls2 == True, 1], c = 'g', s = 10)
ax.legend(targets)
ax.grid()

# %% [markdown]
# ### Linear regression adjustments

# %%
covars = pd.read_csv("../Dataset/Leidinger2011/metadata.csv", index_col=0)

# %%
covars = covars.loc[meta]

# %%
covars["sex"] = covars["sex"] == "f"

# %%
covars = covars.fillna(covars.mean())

# %%
linreg = LinearRegression()
linreg.fit(covars, norm_log_table)
# Out:
# LinearRegression()

# %%
adj_norm_log_table = norm_log_table - linreg.predict(covars)

# %% [markdown]
# # PCA

# %%
pca = decomposition.PCA(n_components=2)

# %%
pca.fit(adj_norm_log_table)
# Out:
# PCA(n_components=2)

# %%
components = pca.transform(adj_norm_log_table)

# %%
components
# Out:
# array([[ -3.05221973,  -6.60308652],
#        [-10.25578427, -11.39605504],
#        [-22.52913201,  -9.00887181],
#        [-17.5520325 , -10.34100821],
#        [ -5.8170015 , -11.92958385],
#        [ -7.09430361,  -8.80462678],
#        [ 20.60905803,  -0.72321305],
#        [ 26.59213611,   3.5837317 ],
#        [ 13.65398357,  -0.74467454],
#        [ 18.26607048,  -0.15443579],
#        [  8.13235909,  -7.9702423 ],
#        [  9.64189704,  -5.60138205],
#        [ 11.83154168,   2.95033623],
#        [ 10.76277146,  -0.04920857],
#        [  9.73176406,   3.59022302],
#        [ 14.96930512,   5.09470037],
#        [ 14.46185294,   4.35403327],
#        [  5.91612667,  -6.89131156],
#        [ -0.83327956,  -2.71851755],
#        [ 12.61742527,   5.61720179],
#        [  1.54712996,   1.4872173 ],
#        [-16.90167565,   0.39287081],
#        [ -2.6091357 ,   4.85583647],
#        [-15.96845885,   1.85905491],
#        [ -0.3769135 ,  12.95798004],
#        [-24.11579982,  -2.57760463],
#        [-12.9940348 ,  -4.91624772],
#        [-14.38780486,  -0.73294075],
#        [ 11.86070369,  -0.21337689],
#        [ 14.40064115,   3.10462751],
#        [ 22.70651806,   5.88215279],
#        [  5.67234464,  -7.43595748],
#        [  4.29229644,  -3.73781829],
#        [ -2.34762739,  -7.23424871],
#        [  1.59855009,  -7.98412909],
#        [ -1.659827  ,  -5.9329179 ],
#        [ -1.07424792,  -6.69908192],
#        [  4.63501217,  -6.71702374],
#        [  9.1856331 ,  -6.22474698],
#        [-12.59647209,   8.90499327],
#        [-13.74243853,  17.48427894],
#        [-21.50423161,   4.0172198 ],
#        [ -9.03387923,  15.60990425],
#        [-19.39569544,   9.82648164],
#        [-13.93493808,  13.17929726],
#        [ -2.94342895,   6.76890682],
#        [ -0.36475821,  11.82126352]])

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Cancer', 'Healthy']
colors = ['r', 'g']
ax.scatter(components[controls == False, 0], components[controls == False, 1], c = 'r', s = 10)
ax.scatter(components[controls == True, 0], components[controls == True, 1], c = 'g', s = 10)
ax.legend(targets)
ax.grid()

# %% [markdown]
# ### Logistic Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(adj_norm_log_table, controls, test_size=0.33, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
plot_roc_curve(model, X_test, y_test)
# Out:
# C:\Users\olefr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### XGBoost

# %%
model = XGBClassifier(use_label_encoder=False)
model.fit(X_train, y_train)
# Out:
# [23:31:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=16,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
plot_roc_curve(model, X_test, y_test)
# Out:
# C:\Users\olefr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### Exporting data

# %%
lookup_table = data.gpls["GPL9040"].table

# %%
lookup_table = lookup_table.set_index("ID")

# %%
mirnas
# Out:
# 0        hsa-miR-130b
# 1         hsa-miR-27b
# 2      hsa-miR-574-3p
# 3         hsa-miR-99a
# 4      hsa-miR-92a-1*
#             ...
# 858       hsa-miR-943
# 859     hsa-miR-551b*
# 860       hsa-miR-380
# 861       hsa-miR-377
# 862      hsa-miR-424*
# Name: ID_REF, Length: 863, dtype: object

# %%
sequences = lookup_table.loc[mirnas]["SEQUENCE"]

# %%
sequences = [s.upper() for s in sequences]

# %%
sequences[:10]
# Out:
# ['CAGUGCAAUGAUGAAAGGGCAU',
#  'UUCACAGUGGCUAAGUUCUGC',
#  'CACGCUCAUGCACACACCCACA',
#  'AACCCGUAGAUCCGAUCUUGUG',
#  'AGGUUGGGAUCGGUUGCAAUGCU',
#  'UCUUGUGUUCUCUAGAUCAGU',
#  'GAUGAUGAUGGCAGCAAAUUCUGAAA',
#  'UGCUUCCUUUCAGAGGGU',
#  'UAUGGCUUUUCAUUCCUAUGUGA',
#  'AUCCUUGCUAUCUGGGUGCUA']

# %%
stages = pd.read_csv("../Dataset/Leidinger2011/stage.csv", index_col=0)

# %%
stages = {s:g for s, g in zip(stages.index, stages["TNM"])}

# %%
stages = [stages[s] if s in stages else 0 for s in meta]

# %%
adj_norm_log_table.columns = sequences
adj_norm_log_table = adj_norm_log_table.loc[:,~adj_norm_log_table.columns.duplicated()]
adj_norm_log_table["cancer"] = sick
adj_norm_log_table["stage"] = stages

# %%
adj_norm_log_table.head()
# Out:
#        CAGUGCAAUGAUGAAAGGGCAU  UUCACAGUGGCUAAGUUCUGC  CACGCUCAUGCACACACCCACA  \
# VALUE                1.215950               0.582302               -0.829594
# VALUE               -0.267868              -0.448137                0.389903
# VALUE               -0.551540              -0.824220                0.362472
# VALUE                0.968880              -0.493288               -0.527174
# VALUE                0.724225              -1.785190                2.082245
#
#        AACCCGUAGAUCCGAUCUUGUG  AGGUUGGGAUCGGUUGCAAUGCU  UCUUGUGUUCUCUAGAUCAGU  \
# VALUE                0.377289                -0.410764               0.287503
# VALUE               -0.871439                 0.314826              -1.299835
# VALUE               -1.094326                -1.322856               0.172794
# VALUE               -0.830863                -0.217630               0.159421
# VALUE               -1.296547                -0.549616               0.887854
#
#        GAUGAUGAUGGCAGCAAAUUCUGAAA  UGCUUCCUUUCAGAGGGU  \
# VALUE                   -0.670987           -0.055568
# VALUE                    0.167228           -0.386828
# VALUE                    2.027047           -1.576708
# VALUE                    0.397605            0.516269
# VALUE                   -0.141949            0.325299
#
#        UAUGGCUUUUCAUUCCUAUGUGA  AUCCUUGCUAUCUGGGUGCUA  ...  \
# VALUE                -1.154821              -0.856366  ...
# VALUE                -1.543413               0.005848  ...
# VALUE                -1.242891              -0.374176  ...
# VALUE                -1.348575              -0.393195  ...
# VALUE                -0.556036               0.703896  ...
#
#        UUUGGCAAUGGUAGAACUCACACU  UCUGCAGGGUUUGCUUUGAG  AGGCAUUGACUUCUCACUAGCU  \
# VALUE                  1.231429              1.303337                0.968270
# VALUE                  0.622837              0.186151                0.887761
# VALUE                 -0.228741             -0.159925                0.858620
# VALUE                 -0.335057              1.230548                1.281374
# VALUE                  0.737985              0.586093                0.584806
#
#        CUGACUGUUGCCGUCCUCCAG  GAAAUCAAGCGUGGGUGAGACC  UAUGUAAUAUGGUCCACAUCUU  \
# VALUE               0.266879                0.036571                0.534357
# VALUE               0.338666               -0.207901               -0.301426
# VALUE              -0.826042                0.755411                0.818436
# VALUE               0.283061                0.184516               -1.038618
# VALUE              -0.539610                0.059786                0.060155
#
#        AUCACACAAAGGCAACUUUUGU  CAAAACGUGAGGCGCUGCUAU  cancer  stage
# VALUE               -0.223134               0.249229    True      1
# VALUE                0.468250              -0.358084    True      3
# VALUE                0.838864              -0.906176    True      1
# VALUE                0.789145              -0.006791    True      1
# VALUE               -0.005040              -0.282394   False      0
#
# [5 rows x 854 columns]

# %%
adj_norm_log_table.to_csv("../TransformedData/Leidinger2011_staged.csv", index=False)
