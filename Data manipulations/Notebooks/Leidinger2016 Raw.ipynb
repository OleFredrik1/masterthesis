# %%
# %matplotlib inline
import GEOparse
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import decomposition
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import explained_variance_score, plot_roc_curve
import statsmodels.api as sm
from scipy.stats import ttest_ind
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklego.linear_model import LowessRegression

# %% [markdown]
# ### Reading in from external source

# %%
data = pd.read_csv("../Dataset/Leidinger2016/data.csv", index_col=0)
metadata = pd.read_csv("../Dataset/Leidinger2016/metadata.csv", index_col=0)

# %%
data
# Out:
#                     427_73    427_203      427_6    427_113    427_204  \
# mirna
# hsa-let-7d-3p    15.932603  15.223523  16.248352  22.413015  13.645375
# hsa-miR-1274A    10.737571  10.574143  11.331379  11.572388  10.042076
# hsa-miR-130b-5p  20.781680  22.014845  21.718082  23.709886  19.100417
# hsa-miR-18b-3p   22.427460  25.036337  25.034230  30.959039  20.030237
# hsa-mir-374a-3p        NaN  35.488431  28.069303        NaN        NaN
# ...                    ...        ...        ...        ...        ...
# hsa-miR-525-5p         NaN        NaN        NaN        NaN        NaN
# hsa-miR-499a-5p        NaN        NaN        NaN        NaN        NaN
# hsa-miR-425-5p   11.527253  11.564897  11.373714  12.954788  10.769821
# hsa-miR-320d     13.790253  13.822623  11.482754  14.114211  15.230916
# hsa-miR-1471           NaN        NaN        NaN        NaN        NaN
#
#                     427_72    427_114  CBC-Std._PAX     427_74    427_144  \
# mirna
# hsa-let-7d-3p    14.738012  22.596233     22.888973  15.866733  24.288934
# hsa-miR-1274A    10.144483  12.356872     10.705495   9.667815  13.633111
# hsa-miR-130b-5p  21.827675  25.048847     36.433345  21.689067  27.451811
# hsa-miR-18b-3p   21.940433  23.854875           NaN  22.811107        NaN
# hsa-mir-374a-3p  26.889067        NaN           NaN        NaN        NaN
# ...                    ...        ...           ...        ...        ...
# hsa-miR-525-5p         NaN        NaN           NaN        NaN        NaN
# hsa-miR-499a-5p        NaN        NaN           NaN        NaN        NaN
# hsa-miR-425-5p   11.765464  15.327691     23.278471  12.285083  20.455999
# hsa-miR-320d     15.462306  18.700562     18.498053  15.015886  18.991811
# hsa-miR-1471           NaN        NaN           NaN        NaN        NaN
#
#                  ...     427_32    427_130    427_195     427_43    427_132  \
# mirna            ...
# hsa-let-7d-3p    ...  15.509471  20.697998  15.889463  15.685995  19.293326
# hsa-miR-1274A    ...  10.679353  13.142619  10.238733  11.271985  15.254062
# hsa-miR-130b-5p  ...  20.099207  25.060506  21.664748  20.498594  26.540182
# hsa-miR-18b-3p   ...  22.284950  23.662515  26.152364  21.575217  23.234337
# hsa-mir-374a-3p  ...  25.392850        NaN        NaN        NaN        NaN
# ...              ...        ...        ...        ...        ...        ...
# hsa-miR-525-5p   ...        NaN        NaN        NaN        NaN        NaN
# hsa-miR-499a-5p  ...        NaN        NaN  33.002006        NaN        NaN
# hsa-miR-425-5p   ...  10.468457  16.415906  11.180775  11.154117  18.681152
# hsa-miR-320d     ...  16.536539  16.667605  15.244845  17.444328  14.184984
# hsa-miR-1471     ...        NaN        NaN        NaN        NaN        NaN
#
#                     427_21     427_51    427_194     427_22    427_131
# mirna
# hsa-let-7d-3p    25.930607  14.996039  15.952217  24.905330  19.285037
# hsa-miR-1274A    12.772054  10.690352  11.481045  12.959969  13.640983
# hsa-miR-130b-5p  26.644933  19.678436  21.797062  25.517612  26.471666
# hsa-miR-18b-3p   24.539601  20.642805  26.419264        NaN  24.594952
# hsa-mir-374a-3p        NaN        NaN        NaN        NaN        NaN
# ...                    ...        ...        ...        ...        ...
# hsa-miR-525-5p         NaN        NaN        NaN        NaN        NaN
# hsa-miR-499a-5p        NaN  27.854501        NaN        NaN        NaN
# hsa-miR-425-5p   16.498625   9.863937  11.245421  16.345123  19.150788
# hsa-miR-320d     23.065737  15.176894  15.470059  19.442010  15.665874
# hsa-miR-1471           NaN        NaN        NaN        NaN        NaN
#
# [241 rows x 121 columns]

# %%
metadata
# Out:
#             Class extraction
# CBCID
# 427_2    0 (Ctrl)   miRNeasy
# 427_3    0 (Ctrl)   miRNeasy
# 427_7    0 (Ctrl)   miRNeasy
# 427_1    0 (Ctrl)   miRNeasy
# 427_10   0 (Ctrl)   miRNeasy
# ...           ...        ...
# 427_194  3 (COPD)   miRNeasy
# 427_195  3 (COPD)   miRNeasy
# 427_196  3 (COPD)   miRNeasy
# 427_197  3 (COPD)   miRNeasy
# 427_198  3 (COPD)   miRNeasy
#
# [120 rows x 2 columns]

# %%
data2 = pd.concat([data.iloc[:].transpose(), metadata], axis=1)

# %%
data2 = data2.dropna(subset=["Class"])

# %%
data2
# Out:
#          hsa-let-7d-3p  hsa-miR-1274A  hsa-miR-130b-5p  hsa-miR-18b-3p  \
# 427_73       15.932603      10.737571        20.781680       22.427460
# 427_203      15.223523      10.574143        22.014845       25.036337
# 427_6        16.248352      11.331379        21.718082       25.034230
# 427_113      22.413015      11.572388        23.709886       30.959039
# 427_204      13.645375      10.042076        19.100417       20.030237
# ...                ...            ...              ...             ...
# 427_21       25.930607      12.772054        26.644933       24.539601
# 427_51       14.996039      10.690352        19.678436       20.642805
# 427_194      15.952217      11.481045        21.797062       26.419264
# 427_22       24.905330      12.959969        25.517612             NaN
# 427_131      19.285037      13.640983        26.471666       24.594952
#
#          hsa-mir-374a-3p  hsa-miR-518e-5p  hsa-miR-595  hsa-miR-634  \
# 427_73               NaN              NaN          NaN          NaN
# 427_203        35.488431              NaN          NaN          NaN
# 427_6          28.069303              NaN          NaN          NaN
# 427_113              NaN              NaN          NaN          NaN
# 427_204              NaN              NaN          NaN          NaN
# ...                  ...              ...          ...          ...
# 427_21               NaN              NaN          NaN          NaN
# 427_51               NaN              NaN          NaN          NaN
# 427_194              NaN              NaN          NaN          NaN
# 427_22               NaN              NaN          NaN          NaN
# 427_131              NaN              NaN          NaN          NaN
#
#          hsa-miR-675-5p  hsa-miR-942-5p  ...  hsa-miR-98-5p  hsa-miR-744-5p  \
# 427_73              NaN        8.608420  ...      21.479600       14.765223
# 427_203             NaN        9.110362  ...      20.942969       15.233210
# 427_6               NaN        9.710889  ...      19.022369       15.480556
# 427_113             NaN       10.937889  ...            NaN       16.846389
# 427_204             NaN        8.237714  ...      20.796972       14.728296
# ...                 ...             ...  ...            ...             ...
# 427_21              NaN       12.575656  ...      23.968691       18.143339
# 427_51              NaN        8.241445  ...      20.385480       13.935923
# 427_194             NaN        8.690464  ...      20.412882       14.900462
# 427_22              NaN       12.872868  ...      22.758393       18.155782
# 427_131             NaN       12.530539  ...            NaN       18.608665
#
#          hsa-miR-598-3p  hsa-miR-525-5p  hsa-miR-499a-5p  hsa-miR-425-5p  \
# 427_73        18.852307             NaN              NaN       11.527253
# 427_203       17.840421             NaN              NaN       11.564897
# 427_6         17.553957             NaN              NaN       11.373714
# 427_113       22.740004             NaN              NaN       12.954788
# 427_204       17.985389             NaN              NaN       10.769821
# ...                 ...             ...              ...             ...
# 427_21        22.656183             NaN              NaN       16.498625
# 427_51        17.096224             NaN        27.854501        9.863937
# 427_194       17.517965             NaN              NaN       11.245421
# 427_22        20.193854             NaN              NaN       16.345123
# 427_131       22.913082             NaN              NaN       19.150788
#
#          hsa-miR-320d  hsa-miR-1471     Class     extraction
# 427_73      13.790253           NaN   2 (LCa)       miRNeasy
# 427_203     13.822623           NaN  3 (COPD)       miRNeasy
# 427_6       11.482754           NaN  0 (Ctrl)       miRNeasy
# 427_113     14.114211           NaN   2 (LCa)  PAXGene Blood
# 427_204     15.230916           NaN  3 (COPD)       miRNeasy
# ...               ...           ...       ...            ...
# 427_21      23.065737           NaN  0 (Ctrl)  PAXGene Blood
# 427_51      15.176894           NaN   2 (LCa)       miRNeasy
# 427_194     15.470059           NaN  3 (COPD)       miRNeasy
# 427_22      19.442010           NaN  0 (Ctrl)  PAXGene Blood
# 427_131     15.665874           NaN   2 (LCa)  PAXGene Blood
#
# [120 rows x 243 columns]

# %%
table = data2.iloc[:, :-2]
mirnas = table.columns

# %%
table
# Out:
#          hsa-let-7d-3p  hsa-miR-1274A  hsa-miR-130b-5p  hsa-miR-18b-3p  \
# 427_73       15.932603      10.737571        20.781680       22.427460
# 427_203      15.223523      10.574143        22.014845       25.036337
# 427_6        16.248352      11.331379        21.718082       25.034230
# 427_113      22.413015      11.572388        23.709886       30.959039
# 427_204      13.645375      10.042076        19.100417       20.030237
# ...                ...            ...              ...             ...
# 427_21       25.930607      12.772054        26.644933       24.539601
# 427_51       14.996039      10.690352        19.678436       20.642805
# 427_194      15.952217      11.481045        21.797062       26.419264
# 427_22       24.905330      12.959969        25.517612             NaN
# 427_131      19.285037      13.640983        26.471666       24.594952
#
#          hsa-mir-374a-3p  hsa-miR-518e-5p  hsa-miR-595  hsa-miR-634  \
# 427_73               NaN              NaN          NaN          NaN
# 427_203        35.488431              NaN          NaN          NaN
# 427_6          28.069303              NaN          NaN          NaN
# 427_113              NaN              NaN          NaN          NaN
# 427_204              NaN              NaN          NaN          NaN
# ...                  ...              ...          ...          ...
# 427_21               NaN              NaN          NaN          NaN
# 427_51               NaN              NaN          NaN          NaN
# 427_194              NaN              NaN          NaN          NaN
# 427_22               NaN              NaN          NaN          NaN
# 427_131              NaN              NaN          NaN          NaN
#
#          hsa-miR-675-5p  hsa-miR-942-5p  ...  hsa-miR-320c  hsa-miR-1299  \
# 427_73              NaN        8.608420  ...     12.054734     18.381541
# 427_203             NaN        9.110362  ...     10.501013     26.472544
# 427_6               NaN        9.710889  ...     11.183694     19.951407
# 427_113             NaN       10.937889  ...     11.187046     18.126288
# 427_204             NaN        8.237714  ...     11.567222     31.446154
# ...                 ...             ...  ...           ...           ...
# 427_21              NaN       12.575656  ...     13.037589     23.646209
# 427_51              NaN        8.241445  ...     11.235713     17.736150
# 427_194             NaN        8.690464  ...     13.371917     22.308426
# 427_22              NaN       12.872868  ...     11.775947     23.305037
# 427_131             NaN       12.530539  ...     14.288258     29.662125
#
#          hsa-miR-98-5p  hsa-miR-744-5p  hsa-miR-598-3p  hsa-miR-525-5p  \
# 427_73       21.479600       14.765223       18.852307             NaN
# 427_203      20.942969       15.233210       17.840421             NaN
# 427_6        19.022369       15.480556       17.553957             NaN
# 427_113            NaN       16.846389       22.740004             NaN
# 427_204      20.796972       14.728296       17.985389             NaN
# ...                ...             ...             ...             ...
# 427_21       23.968691       18.143339       22.656183             NaN
# 427_51       20.385480       13.935923       17.096224             NaN
# 427_194      20.412882       14.900462       17.517965             NaN
# 427_22       22.758393       18.155782       20.193854             NaN
# 427_131            NaN       18.608665       22.913082             NaN
#
#          hsa-miR-499a-5p  hsa-miR-425-5p  hsa-miR-320d  hsa-miR-1471
# 427_73               NaN       11.527253     13.790253           NaN
# 427_203              NaN       11.564897     13.822623           NaN
# 427_6                NaN       11.373714     11.482754           NaN
# 427_113              NaN       12.954788     14.114211           NaN
# 427_204              NaN       10.769821     15.230916           NaN
# ...                  ...             ...           ...           ...
# 427_21               NaN       16.498625     23.065737           NaN
# 427_51         27.854501        9.863937     15.176894           NaN
# 427_194              NaN       11.245421     15.470059           NaN
# 427_22               NaN       16.345123     19.442010           NaN
# 427_131              NaN       19.150788     15.665874           NaN
#
# [120 rows x 241 columns]

# %%
mirnas
# Out:
# Index(['hsa-let-7d-3p', 'hsa-miR-1274A', 'hsa-miR-130b-5p', 'hsa-miR-18b-3p',
#        'hsa-mir-374a-3p', 'hsa-miR-518e-5p', 'hsa-miR-595', 'hsa-miR-634',
#        'hsa-miR-675-5p', 'hsa-miR-942-5p',
#        ...
#        'hsa-miR-320c', 'hsa-miR-1299', 'hsa-miR-98-5p', 'hsa-miR-744-5p',
#        'hsa-miR-598-3p', 'hsa-miR-525-5p', 'hsa-miR-499a-5p', 'hsa-miR-425-5p',
#        'hsa-miR-320d', 'hsa-miR-1471'],
#       dtype='object', length=241)

# %% [markdown]
# ### Seperate case and controls

# %%
sick = data2["Class"] == "2 (LCa)"
controls = 1 - sick

# %%
sum(controls)
# Out:
# 46

# %% [markdown]
# ### Drop NAN

# %%
table = table.fillna(table.max().max())

# %% [markdown]
# ### T-test

# %%
X = table

# %%
X.columns
# Out:
# Index(['hsa-let-7d-3p', 'hsa-miR-1274A', 'hsa-miR-130b-5p', 'hsa-miR-18b-3p',
#        'hsa-mir-374a-3p', 'hsa-miR-518e-5p', 'hsa-miR-595', 'hsa-miR-634',
#        'hsa-miR-675-5p', 'hsa-miR-942-5p',
#        ...
#        'hsa-miR-320c', 'hsa-miR-1299', 'hsa-miR-98-5p', 'hsa-miR-744-5p',
#        'hsa-miR-598-3p', 'hsa-miR-525-5p', 'hsa-miR-499a-5p', 'hsa-miR-425-5p',
#        'hsa-miR-320d', 'hsa-miR-1471'],
#       dtype='object', length=241)

# %%
X_healthy, X_cancer = X[controls == 1], X[sick == 1]

# %%
results = ttest_ind(X_healthy, X_cancer).pvalue

# %%
lowest, pvalues = np.argsort(results)[:5], np.sort(results)[:5]

# %%
mirnas[lowest], pvalues
# Out:
# (Index(['hsa-miR-452-3p', 'hsa-miR-1252-5p', 'hsa-miR-525-5p', 'cel-miR-39-3p',
#         'hsa-miR-767-3p'],
#        dtype='object'),
#  array([9.21371079e-19, 9.21371079e-19, 9.21371079e-19, 9.21371079e-19,
#         9.21371079e-19]))

# %% [markdown]
# ### F-test

# %%
t3 = table

# %%
f, p = f_classif(t3, sick)

# %%
np.mean(p)
# Out:
# 0.2011752391308669

# %% [markdown]
# ### ANOVA

# %%
t3
# Out:
#          hsa-let-7d-3p  hsa-miR-1274A  hsa-miR-130b-5p  hsa-miR-18b-3p  \
# 427_73       15.932603      10.737571        20.781680       22.427460
# 427_203      15.223523      10.574143        22.014845       25.036337
# 427_6        16.248352      11.331379        21.718082       25.034230
# 427_113      22.413015      11.572388        23.709886       30.959039
# 427_204      13.645375      10.042076        19.100417       20.030237
# ...                ...            ...              ...             ...
# 427_21       25.930607      12.772054        26.644933       24.539601
# 427_51       14.996039      10.690352        19.678436       20.642805
# 427_194      15.952217      11.481045        21.797062       26.419264
# 427_22       24.905330      12.959969        25.517612       38.204715
# 427_131      19.285037      13.640983        26.471666       24.594952
#
#          hsa-mir-374a-3p  hsa-miR-518e-5p  hsa-miR-595  hsa-miR-634  \
# 427_73         38.204715        38.204715    38.204715    38.204715
# 427_203        35.488431        38.204715    38.204715    38.204715
# 427_6          28.069303        38.204715    38.204715    38.204715
# 427_113        38.204715        38.204715    38.204715    38.204715
# 427_204        38.204715        38.204715    38.204715    38.204715
# ...                  ...              ...          ...          ...
# 427_21         38.204715        38.204715    38.204715    38.204715
# 427_51         38.204715        38.204715    38.204715    38.204715
# 427_194        38.204715        38.204715    38.204715    38.204715
# 427_22         38.204715        38.204715    38.204715    38.204715
# 427_131        38.204715        38.204715    38.204715    38.204715
#
#          hsa-miR-675-5p  hsa-miR-942-5p  ...  hsa-miR-320c  hsa-miR-1299  \
# 427_73        38.204715        8.608420  ...     12.054734     18.381541
# 427_203       38.204715        9.110362  ...     10.501013     26.472544
# 427_6         38.204715        9.710889  ...     11.183694     19.951407
# 427_113       38.204715       10.937889  ...     11.187046     18.126288
# 427_204       38.204715        8.237714  ...     11.567222     31.446154
# ...                 ...             ...  ...           ...           ...
# 427_21        38.204715       12.575656  ...     13.037589     23.646209
# 427_51        38.204715        8.241445  ...     11.235713     17.736150
# 427_194       38.204715        8.690464  ...     13.371917     22.308426
# 427_22        38.204715       12.872868  ...     11.775947     23.305037
# 427_131       38.204715       12.530539  ...     14.288258     29.662125
#
#          hsa-miR-98-5p  hsa-miR-744-5p  hsa-miR-598-3p  hsa-miR-525-5p  \
# 427_73       21.479600       14.765223       18.852307       38.204715
# 427_203      20.942969       15.233210       17.840421       38.204715
# 427_6        19.022369       15.480556       17.553957       38.204715
# 427_113      38.204715       16.846389       22.740004       38.204715
# 427_204      20.796972       14.728296       17.985389       38.204715
# ...                ...             ...             ...             ...
# 427_21       23.968691       18.143339       22.656183       38.204715
# 427_51       20.385480       13.935923       17.096224       38.204715
# 427_194      20.412882       14.900462       17.517965       38.204715
# 427_22       22.758393       18.155782       20.193854       38.204715
# 427_131      38.204715       18.608665       22.913082       38.204715
#
#          hsa-miR-499a-5p  hsa-miR-425-5p  hsa-miR-320d  hsa-miR-1471
# 427_73         38.204715       11.527253     13.790253     38.204715
# 427_203        38.204715       11.564897     13.822623     38.204715
# 427_6          38.204715       11.373714     11.482754     38.204715
# 427_113        38.204715       12.954788     14.114211     38.204715
# 427_204        38.204715       10.769821     15.230916     38.204715
# ...                  ...             ...           ...           ...
# 427_21         38.204715       16.498625     23.065737     38.204715
# 427_51         27.854501        9.863937     15.176894     38.204715
# 427_194        38.204715       11.245421     15.470059     38.204715
# 427_22         38.204715       16.345123     19.442010     38.204715
# 427_131        38.204715       19.150788     15.665874     38.204715
#
# [120 rows x 241 columns]

# %%
X = np.array(sick).reshape(-1, 1)

# %%
linreg = LinearRegression()
linreg.fit(X, t3)
# Out:
# LinearRegression()

# %%
fitted = linreg.predict(X)
explained_variance_score(t3, fitted)
# Out:
# 0.1063525793006118

# %% [markdown]
# ### Mean-variance-plot

# %%
np.mean(table)
# Out:
# hsa-let-7d-3p      18.720035
# hsa-miR-1274A      11.569191
# hsa-miR-130b-5p    23.045338
# hsa-miR-18b-3p     25.378931
# hsa-mir-374a-3p    36.238190
#                      ...
# hsa-miR-525-5p     38.204715
# hsa-miR-499a-5p    35.772462
# hsa-miR-425-5p     13.583900
# hsa-miR-320d       19.192923
# hsa-miR-1471       38.166583
# Length: 241, dtype: float64

# %%
def get_means_and_variances(table):
    return np.mean(table), np.var(table, ddof=1)

# %%
def mean_variance_plot(table):
    means, variances = get_means_and_variances(table)
    plt.scatter(means, variances)
    plt.xlabel("mean")
    plt.ylabel("variance")
    plt.plot()

# %%
mean_variance_plot(table)

# %% [markdown]
# ### Log transformation

# %%
log_table = table #np.log2(table)

# %%
mean_variance_plot(log_table)

# %% [markdown]
# ### Remove mean

# %%
log_table = table
norm_log_table = log_table #- np.mean(log_table)
#norm_log_table /= np.sqrt(np.mean(np.var(norm_log_table, ddof=1)))

# %%
mean_variance_plot(norm_log_table)

# %% [markdown]
# ### PCA

# %%
pca = decomposition.PCA(n_components=10)

# %%
pca.fit(norm_log_table)
# Out:
# PCA(n_components=10)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.44161885, 0.0544275 , 0.04052915, 0.03123651, 0.03061332,
#        0.0238692 , 0.01992795, 0.01956578, 0.01754609, 0.01594461])

# %%
components = pca.transform(norm_log_table)

# %%
components.shape
# Out:
# (120, 10)

# %%
sum(controls)
# Out:
# 46

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Cancer', 'Healthy']
colors = ['r', 'g']
ax.scatter(components[controls == False, 0], components[controls == False, 1], c = 'r', s = 10)
ax.scatter(components[controls == True, 0], components[controls == True, 1], c = 'g', s = 10)
ax.legend(targets)
ax.grid()

# %%
components2 = components[components[:,0] < 20, :]
controls2 = controls[components[:,0] < 20]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Cancer', 'Healthy']
colors = ['r', 'g']
ax.scatter(components2[controls2 == False, 0], components2[controls2 == False, 1], c = 'r', s = 10)
ax.scatter(components2[controls2 == True, 0], components2[controls2 == True, 1], c = 'g', s = 10)
ax.legend(targets)
ax.grid()

# %% [markdown]
# ### Logistic Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(norm_log_table, controls, test_size=0.33, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# C:\Users\olefr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
plot_roc_curve(model, X_test, y_test)
# Out:
# C:\Users\olefr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### XGBoost

# %%
model = XGBClassifier(use_label_encoder=False)
model.fit(X_train, y_train)
# Out:
# [18:58:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=16,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
plot_roc_curve(model, X_test, y_test)
# Out:
# C:\Users\olefr\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### Export data

# %%
mirnas = table.columns

# %%
mirnas = [m.replace("A", "a").replace("B", "b").replace("P", "p") for m in mirnas]

# %%
from Scripts import converters

# %%
sequences = converters.canonical_to_seq(mirnas, True)

# %%
sequences = np.array(sequences)
mask = sequences != None
norm_log_table = norm_log_table.loc[:, mask]
sequences = sequences[mask]

# %%
norm_log_table.columns = sequences
norm_log_table = norm_log_table.loc[:,~norm_log_table.columns.duplicated()]
norm_log_table *= -1
norm_log_table["cancer"] = sick
norm_log_table.head()
# Out:
#          CUAUACGACCUGCUGCCUUUCU  ACUCUUUCCCUGUUGCACUAC  \
# 427_73               -15.932603             -20.781680
# 427_203              -15.223523             -22.014845
# 427_6                -16.248352             -21.718082
# 427_113              -22.413015             -23.709886
# 427_204              -13.645375             -19.100417
#
#          UGCCCUAAAUGCCCCUUCUGGC  CUCUAGAGGGAAGCGCUUUCUG  \
# 427_73               -22.427460              -38.204715
# 427_203              -25.036337              -38.204715
# 427_6                -25.034230              -38.204715
# 427_113              -30.959039              -38.204715
# 427_204              -20.030237              -38.204715
#
#          GAAGUGUGCCGUGGUGUGUCU  AACCAGCACCCCAACUUUGGAC  \
# 427_73              -38.204715              -38.204715
# 427_203             -38.204715              -38.204715
# 427_6               -38.204715              -38.204715
# 427_113             -38.204715              -38.204715
# 427_204             -38.204715              -38.204715
#
#          UGGUGCGGAGAGGGCCCACAGUG  UCUUCUCUGUUUUGGCCAUGUG  \
# 427_73                -38.204715               -8.608420
# 427_203               -38.204715               -9.110362
# 427_6                 -38.204715               -9.710889
# 427_113               -38.204715              -10.937889
# 427_204               -38.204715               -8.237714
#
#          CUAUACGGCCUCCUAGCUUUCC  CAUCUUCCAGUACAGUGUUGGA  ...  \
# 427_73               -23.516551              -32.420028  ...
# 427_203              -38.204715              -33.265693  ...
# 427_6                -23.898073              -33.667729  ...
# 427_113              -26.383409              -35.322204  ...
# 427_204              -22.575666              -31.917765  ...
#
#          UUCUGGAAUUCUGUGUGAGGGA  UGAGGUAGUAAGUUGUAUUGUU  \
# 427_73               -18.381541              -21.479600
# 427_203              -26.472544              -20.942969
# 427_6                -19.951407              -19.022369
# 427_113              -18.126288              -38.204715
# 427_204              -31.446154              -20.796972
#
#          UGCGGGGCUAGGGCUAACAGCA  UACGUCAUCGUUGUCAUCGUCA  \
# 427_73               -14.765223              -18.852307
# 427_203              -15.233210              -17.840421
# 427_6                -15.480556              -17.553957
# 427_113              -16.846389              -22.740004
# 427_204              -14.728296              -17.985389
#
#          CUCCAGAGGGAUGCACUUUCU  UUAAGACUUGCAGUGAUGUUU  \
# 427_73              -38.204715             -38.204715
# 427_203             -38.204715             -38.204715
# 427_6               -38.204715             -38.204715
# 427_113             -38.204715             -38.204715
# 427_204             -38.204715             -38.204715
#
#          AAUGACACGAUCACUCCCGUUGA  AAAAGCUGGGUUGAGAGGA  GCCCGCGUGUGGAGCCAGGUGU  \
# 427_73                -11.527253           -13.790253              -38.204715
# 427_203               -11.564897           -13.822623              -38.204715
# 427_6                 -11.373714           -11.482754              -38.204715
# 427_113               -12.954788           -14.114211              -38.204715
# 427_204               -10.769821           -15.230916              -38.204715
#
#          cancer
# 427_73     True
# 427_203   False
# 427_6     False
# 427_113    True
# 427_204   False
#
# [5 rows x 220 columns]

# %%
norm_log_table.to_csv("../TransformedData/Leidinger2016_raw.csv", index=False)
