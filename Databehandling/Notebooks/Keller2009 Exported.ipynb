# %%
# %matplotlib inline
import GEOparse
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import decomposition
from sklearn.feature_selection import f_classif
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import explained_variance_score, plot_roc_curve
import statsmodels.api as sm
from scipy.stats import ttest_ind
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklego.linear_model import LowessRegression
geo = "GSE17681"

# %%
data = GEOparse.get_GEO(geo=geo, destdir="../Dataset/Keller2009", silent=True)

# %%
list(data.gsms.values())[0].metadata
# Out:
# {'title': ['Tumor Sample 1'],
#  'geo_accession': ['GSM441129'],
#  'status': ['Public on Sep 24 2009'],
#  'submission_date': ['Aug 17 2009'],
#  'last_update_date': ['Sep 24 2009'],
#  'type': ['RNA'],
#  'channel_count': ['1'],
#  'source_name_ch1': ['blood of tumor patient'],
#  'organism_ch1': ['Homo sapiens'],
#  'taxid_ch1': ['9606'],
#  'characteristics_ch1': ['class label: lung tumor'],
#  'molecule_ch1': ['total RNA'],
#  'extract_protocol_ch1': ['It is a known fact that that gene expression in peripheral blood changes post-phlebotomically within a few minutes via transcript induction and degradation (Rainen, Oelmueller et al. 2002; Kruhoffer, Dyrskjot et al. 2007).  To counter this problem, the PAXgeneTM blood sample tubes have been developed. These tubes contain a solution that lyses blood cells and at the same time stabilizes the RNA. By that, the ex vivo changes of expression profiles are avoided. The RNA can be stabilized by PAXgeneâ„¢ system can stabilize RNA for three days at 18-25Â°C, for five days at 2-8Â°C, and over a longer period (at least 6 months) at -20Â°C to -70Â°C. The PAXgeneâ„¢ tubes contain 6,9 ml of RNA stabilizing solution and are suitable for the sampling of 2,5 ml blood per tube. Two tubes at 2,5 ml blood were sampled from each patient and healthy blood donor, which equals 5 ml per person. After 8-10fold reversal of the tubes, they were stored over night at 4Â°C. For a longer storage over several days tubes were frozen at -20Â°C. Before RNA isolation the blood was incubated for at least 2 hours at room temperature (RT).  2 Isolation of total RNA including miRNA    The contents of both blood sampling tubes of each patient and healthy donor was pooled and centrifuged at 5000 g for 10 min at room temperature. The supernatant was discarded while the pellet was resuspended in 10 ml RNase free water by vortex. The suspension is again centrifuged at 5000 g for 10 min at RT. Subsequently, the total RNA including the miRNA was isolated using the miRNeasy kit (Qiagen GmbH, Hilden). Therefore the pellet was resuspended in 700 Î¼l QIAzol lysis reagent and incubated for 5 min at RT. Then, 140 Î¼l chloroform were added, vortexed for 15 sec, and incubated for 2-3 min at RT. This was followed by a centrifugation at 14000 rpm and 4Â°C for 15 min. The upper, watery phase was removed and 1,5 times of its volume added in 100% ethanol (ca. 900 Î¼l). Each 700 Î¼l of this mixture were placed on a column and centrifuged at 13000 rpm at RT for 15 sec. After the mixture had completely passed the column, 700 Î¼l of Buffer RWT were added to each column, and again centrifuged at 13000 rpm at RT for 15 sec. Following this, 500 Î¼l Buffer RPL were added to the column and centrifuged at 13000 rpm at RT for 15 sec. After this, another 500 Î¼l Buffer RPL  were added to the column and centrifuged at 13000 rpm at RT for 2 min. The column was then centrifuged at 13000 rpm and RT for 1 min to dry it. The following was the elution step  with 40 Î¼l RNase free water, centrifuging at 13000 rpm at RT for 1 min. The eluted RNA was stored at -70Â°C.'],
#  'label_ch1': ['biotin'],
#  'label_protocol_ch1': ['Sample labeling with biotin has been carried out either by using the miRVANAâ„¢ miRNA Labeling Kit (Applied Biosystems Inc, Foster City, California USA) or by microfluidic-based enzymatic on-chip labeling of miRNAs (MPEA).'],
#  'hyb_protocol': ['Hybridization for 16 hours at 42Â°C has been carried out overnight according to manufacturs instructions. Then, the biochip was washed automatically and a program for signal enhancement was processed with the Geniom Real Time Analyzer'],
#  'scan_protocol': ['The resulting detection pictures were evaluated using the Geniom Wizard Software.'],
#  'description': ['none'],
#  'data_processing': ['For each array, the median signal intensity was extracted from the raw data file such that for each miRNA seven intensity values have been calculated corresponding to each replicate copy of miRBase on the array. Following background subtraction the seven replicate intensity values of each miRNA were summarized by their median value. To normalize the data across different arrays, quantile normalizatio  was applied.'],
#  'platform_id': ['GPL9040'],
#  'contact_name': ['Andreas,,Keller'],
#  'contact_institute': ['Saarland University'],
#  'contact_address': ['Building 60'],
#  'contact_city': ['Homburg'],
#  'contact_zip/postal_code': ['69112'],
#  'contact_country': ['Germany'],
#  'supplementary_file': ['NONE'],
#  'series_id': ['GSE17681'],
#  'data_row_count': ['866']}

# %%
data.gpls["GPL9040"].table
# Out:
#                  ID                   SEQUENCE        miRNA_ID
# 0       hsa-miR-126     ucguaccgugaguaauaaugcg     hsa-miR-126
# 1    hsa-miR-423-5p    ugaggggcagagagcgagacuuu  hsa-miR-423-5p
# 2        hsa-let-7i     ugagguaguaguuugugcuguu      hsa-let-7i
# 3        hsa-let-7d     agagguaguagguugcauaguu      hsa-let-7d
# 4        hsa-miR-22     aagcugccaguugaagaacugu      hsa-miR-22
# ..              ...                        ...             ...
# 861     hsa-miR-92a     uauugcacuugucccggccugu     hsa-miR-92a
# 862  hsa-miR-29b-1*   gcugguuucauauggugguuuaga  hsa-miR-29b-1*
# 863     hsa-miR-150     ucucccaacccuuguaccagug     hsa-miR-150
# 864     hsa-miR-335    ucaagagcaauaacgaaaaaugu     hsa-miR-335
# 865     hsa-miR-638  agggaucgcgggcggguggcggccu     hsa-miR-638
#
# [866 rows x 3 columns]

# %%
table = pd.concat((val.table.iloc[:,1:] for i,val in enumerate(data.gsms.values())), axis=1).transpose()
mirnas = list(data.gsms.values())[0].table.iloc[:,0]

# %%
table
# Out:
#           0      1       2       3       4       5      6       7       8    \
# VALUE   84.17   1.00  119.33    1.00   23.56  288.00   1.00   41.28  101.11
# VALUE   26.78   1.00   58.78    9.11    1.00   69.78   1.00   32.78   51.11
# VALUE   18.78   1.00   82.06    1.00   22.67  256.44   1.00   38.33   49.56
# VALUE   47.56   1.00   98.00   15.89   75.33  254.28   1.00   52.44   52.44
# VALUE   29.11   1.00   60.22    4.78   34.22  121.44   1.00   29.11   75.94
# VALUE    1.00   1.00   57.00    1.00    1.00   32.00   1.00    1.00   32.00
# VALUE   137.22   1.00    1.00
# VALUE    83.33   1.56    1.00
# VALUE    98.00   2.22    2.22
# VALUE   112.44   1.00    1.00
# VALUE   367.06  21.78    1.00
# VALUE   557.44  21.56    1.00
# VALUE   172.44   1.56    1.00
# VALUE   746.29  12.00    1.00
# VALUE    67.44   1.00    4.22
# VALUE     1.00   1.00   53.33
# VALUE     1.00   1.00    1.00
# VALUE     1.00   4.44   30.44
# VALUE    86.67   1.00    1.00
# VALUE     1.00  11.33  334.78
# VALUE     1.00   1.00    1.00
# VALUE     1.00   1.00    1.00
# VALUE    58.89   1.00    4.44
# VALUE   312.11  16.33    4.44
# VALUE    90.78  30.44   12.44
# VALUE   129.44  14.89   14.89
# VALUE   234.33  12.11    1.00
# VALUE    57.00  21.89    1.00
# VALUE    58.89   1.00    1.00
#
# [36 rows x 866 columns]

# %% [markdown]
# ### Seperate case and controls

# %%
sick = np.array(["Tumor" in k.metadata["title"][0] for k in list(data.gsms.values())])
controls = 1 - sick

# %%
sum(controls)
# Out:
# 19

# %% [markdown]
# ### Remove constant values

# %%
mask = table.std() != 0
table = table.loc[:, mask]
mirnas = mirnas[mask]

# %% [markdown]
# ### T-test

# %%
X = table

# %%
X
# Out:
#           0      1       2       3       4       5      6       7       8    \
# VALUE   84.17   1.00  119.33    1.00   23.56  288.00   1.00   41.28  101.11
# VALUE   26.78   1.00   58.78    9.11    1.00   69.78   1.00   32.78   51.11
# VALUE   18.78   1.00   82.06    1.00   22.67  256.44   1.00   38.33   49.56
# VALUE   47.56   1.00   98.00   15.89   75.33  254.28   1.00   52.44   52.44
# VALUE   29.11   1.00   60.22    4.78   34.22  121.44   1.00   29.11   75.94
# VALUE    1.00   1.00   57.00    1.00    1.00   32.00   1.00    1.00   32.00
# VALUE   52.00  15.78    1.00    1.00    1.00   15.78   1.00    2.67   15.78
# VALUE   14.89   1.00    2.67    1.00    1.00   21.44   1.00    1.00   55.56
# VALUE    1.00  48.00    1.00    1.00    1.00   27.89   1.00    1.00   57.00
# VALUE    4.00  58.67   20.56    1.00    1.00   28.00   1.00    1.00   81.11
# VALUE   20.56  79.67   20.56    1.00    1.00   20.56   1.00    1.00   31.56
# VALUE   16.78   7.89   58.00    1.00    1.00   27.00   1.00    1.00   46.89
# VALUE    5.22  69.56   37.67    5.22    1.00   31.56  12.22   12.22   25.17
# VALUE   24.56   1.00   24.56    6.78    1.00   48.00   1.00    6.78    6.78
# VALUE    8.44   1.00   39.67    1.00    1.56   61.56   1.00    1.00   61.56
# VALUE   24.00   9.56   30.44    1.00   16.44   43.11   9.56    9.56    2.22
# VALUE   31.11   1.00   69.67    1.00    4.00   98.00   1.00   13.00   31.11
# VALUE   28.00   1.00  130.44   18.67   61.56  192.67   1.00   61.56   34.44
# VALUE   36.11   1.00   70.67    1.00  132.00   80.56   1.56   55.22   28.44
# VALUE   11.56   1.00   31.33    1.00  108.00   47.06   1.56   11.56   73.33
# VALUE    5.11   1.00   64.72   20.56   72.22   91.89   1.00   39.22   12.00
# VALUE    1.00   1.00  149.33    4.22    1.00  149.33   4.22  286.11   67.44
# VALUE  109.67   1.00  109.67    1.00   18.72   18.72  53.33   18.72    1.00
# VALUE    1.00   1.00    1.00    1.00    1.00    1.00   1.
# VALUE   28.33  ...   4.22     1.00   8310.31     1.00   4.22   1.00    1.00
# VALUE   53.33  ...  18.72     1.00   8310.31   773.97  18.72   1.00    1.00
# VALUE   40.78  ...   1.00  1732.86   6795.89  2099.43   1.00   1.00    1.00
# VALUE   77.44  ...   1.00  1492.75   8310.31   388.00   4.44  77.44    1.00
# VALUE  382.00  ...   1.00  1344.42  11838.82     1.00   1.00   1.00   86.67
# VALUE   11.33  ...   1.00   700.50   7978.50     1.00  35.83   1.00    1.00
# VALUE    3.67  ...  49.22  1797.04   8969.72   586.78   3.67  22.22    1.00
# VALUE  105.33  ...  12.00   579.35  13307.74   511.89  12.00  12.00   12.00
# VALUE   30.22  ...  18.11  2223.89   4106.11    97.67   1.00   1.00   18.11
# VALUE    4.44  ...  58.78  1297.51  10521.90     1.00   4.44  58.78    4.44
# VALUE    1.00  ...  30.44   234.33  10047.96     1.00   1.00   1.00   57.00
# VALUE    1.00  ...  29.44  1101.78  10047.96     1.00   3.11   3.11   29.44
# VALUE   98.56  ...  12.11     1.00   8969.72   234.33   1.00   1.00    1.00
# VALUE   10.44  ...  10.44   606.46   9312.50   950.97   1.00   1.00   44.00
# VALUE   46.11  ...   1.00   901.96   8626.43   674.69   1.00  11.33    1.00
#
#            863    864     865
# VALUE   192.67  58.00    1.00
# VALUE   408.44  13.72    1.00
# VALUE   458.72   1.00    1.00
# VALUE  1297.51  34.44    9.56
# VALUE   320.78  12.00    1.00
# VALUE    75.33   1.00    1.00
# VALUE   209.67   1.00    1.00
# VALUE    55.56   1.00    1.00
# VALUE    48.00   1.00    1.00
# VALUE    47.39   1.00    1.00
# VALUE    73.33   8.44    1.00
# VALUE    90.44  16.78    1.00
# VALUE   127.11   1.00    1.00
# VALUE   137.22   1.00    1.00
# VALUE    83.33   1.56    1.00
# VALUE    98.00   2.22    2.22
# VALUE   112.44   1.00    1.00
# VALUE   367.06  21.78    1.00
# VALUE   557.44  21.56    1.00
# VALUE   172.44   1.56    1.00
# VALUE   746.29  12.00    1.00
# VALUE    67.44   1.00    4.22
# VALUE     1.00   1.00   53.33
# VALUE     1.00   1.00    1.00
# VALUE     1.00   4.44   30.44
# VALUE    86.67   1.00    1.00
# VALUE     1.00  11.33  334.78
# VALUE     1.00   1.00    1.00
# VALUE     1.00   1.00    1.00
# VALUE    58.89   1.00    4.44
# VALUE   312.11  16.33    4.44
# VALUE    90.78  30.44   12.44
# VALUE   129.44  14.89   14.89
# VALUE   234.33  12.11    1.00
# VALUE    57.00  21.89    1.00
# VALUE    58.89   1.00    1.00
#
# [36 rows x 865 columns]

# %%
X_healthy, X_cancer = X[controls == 1], X[sick == 1]

# %%
results = ttest_ind(X_healthy, X_cancer).pvalue

# %%
lowest, pvalues = np.argsort(results)[:5], np.sort(results)[:5]

# %%
mirnas.iloc[lowest], pvalues
# Out:
# (501       hsa-miR-126
#  526    hsa-miR-423-5p
#  701        hsa-let-7d
#  206        hsa-let-7i
# VALUE    4.44  ...  58.78  1297.51  10521.90     1.00   4.44  58.78    4.44
# VALUE    1.00  ...  30.44   234.33  10047.96     1.00   1.00   1.00   57.00
# VALUE    1.00  ...  29.44  1101.78  10047.96     1.00   3.11   3.11   29.44
# VALUE   98.56  ...  12.11     1.00   8969.72   234.33   1.00   1.00    1.00
# VALUE   10.44  ...  10.44   606.46   9312.50   950.97   1.00   1.00   44.00
# VALUE   46.11  ...   1.00   901.96   8626.43   674.69   1.00  11.33    1.00
#
#            863    864     865
# VALUE   192.67  58.00    1.00
# VALUE   408.44  13.72    1.00
# VALUE   458.72   1.00    1.00
# VALUE  1297.51  34.44    9.56
# VALUE   320.78  12.00    1.00
# VALUE    75.33   1.00    1.00
# VALUE   209.67   1.00    1.00
# VALUE    55.56   1.00    1.00
# VALUE    48.00   1.00    1.00
# VALUE    47.39   1.00    1.00
# VALUE    73.33   8.44    1.00
# VALUE    90.44  16.78    1.00
# VALUE   127.11   1.00    1.00
# VALUE   137.22   1.00    1.00
# VALUE    83.33   1.56    1.00
# VALUE    98.00   2.22    2.22
# VALUE   112.44   1.00    1.00
# VALUE   367.06  21.78    1.00
# VALUE   557.44  21.56    1.00
# VALUE   172.44   1.56    1.00
# VALUE   746.29  12.00    1.00
# VALUE    67.44   1.00    4.22
# VALUE     1.00   1.00   53.33
# VALUE     1.00   1.00    1.00
# VALUE     1.00   4.44   30.44
# VALUE    86.67   1.00    1.00
# VALUE     1.00  11.33  334.78
# VALUE     1.00   1.00    1.00
# VALUE     1.00   1.00    1.00
# VALUE    58.89   1.00    4.44
# VALUE   312.11  16.33    4.44
# VALUE    90.78  30.44   12.44
# VALUE   129.44  14.89   14.89
# VALUE   234.33  12.11    1.00
# VALUE    57.00  21.89    1.00
# VALUE    58.89   1.00    1.00
#
# [36 rows x 865 columns]

# %%
X = np.array(sick).reshape(-1, 1)

# %%
linreg = LinearRegression()
linreg.fit(X, t3)
# Out:
# LinearRegression()

# %%
fitted = linreg.predict(X)
explained_variance_score(t3, fitted)
# Out:
# 0.06576031813134062

# %% [markdown]
# ### Mean-variance-plot

# %%
np.mean(table)
# Out:
# 0       29.557500
# 1       13.077500
# 2       51.201111
# 3       14.908889
# 4       26.078333
#           ...
# 861      7.447500
# 862     18.318333
# 863    188.353333
# 864      9.235833
# 865     13.798889
# Length: 865, dtype: float64

# %%
def get_means_and_variances(table):
    return np.mean(table), np.var(table, ddof=1)

# %%
def mean_variance_plot(table):
    means, variances = get_means_and_variances(table)
    plt.scatter(means, variances)
    plt.xlabel("mean")
    plt.ylabel("variance")
    plt.plot()

# %%
mean_variance_plot(table)

# %% [markdown]
# ### Log transformation

# %%
log_table = np.log2(table)

# %%
mean_variance_plot(log_table)

# %%
mask = np.mean(log_table) > 3
log_table = log_table.loc[:, mask]
mirnas = mirnas[mask]

# %% [markdown]
# ### Loess regression

# %%
lowess = LowessRegression(sigma=1, span=0.1)

# %%
means, variances = get_means_and_variances(log_table)
lowess.fit(means.to_numpy().reshape(-1,1), variances)
# Out:
# LowessRegression(span=0.1)

# %%
x_axis = np.linspace(-2, 14, 100)
y_axis = lowess.predict(x_axis.reshape(-1,1))

# %%
plt.scatter(means, variances, color="b")
plt.scatter(x_axis, y_axis, color="y")
plt.xlabel("mean")
plt.ylabel("variance")
plt.legend(["Sample points", "Lowess regression"])
plt.plot()
# Out:
# []

# %% [markdown]
# ### Lowess normalization

# %%
adj_var = lowess.predict(means.to_numpy().reshape(-1, 1))

# %%
log_table /= np.sqrt(adj_var)

# %%
mean_variance_plot(log_table)

# %%
norm_log_table = log_table - np.mean(log_table)

# %%
norm_log_table /= np.sqrt(np.mean(np.var(norm_log_table, ddof=1)))

# %%
mean_variance_plot(norm_log_table)

# %% [markdown]
# ### PCA

# %%
pca = decomposition.PCA(n_components=10)

# %%
pca.fit(norm_log_table)
# Out:
# PCA(n_components=10)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.22965804, 0.18556868, 0.10786282, 0.06986837, 0.04634162,
#        0.03587015, 0.03333122, 0.03226824, 0.02836934, 0.02741108])

# %%
components = pca.transform(norm_log_table)

# %%
components.shape
# Out:
# (36, 10)

# %%
sum(controls)
# Out:
# 19

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Cancer', 'Healthy']
colors = ['r', 'g']
ax.scatter(components[controls == False, 0], components[controls == False, 1], c = 'r', s = 10)
ax.scatter(components[controls == True, 0], components[controls == True, 1], c = 'g', s = 10)
ax.legend(targets)
ax.grid()

# %%
components2 = components[components[:,0] < 20, :]
controls2 = controls[components[:,0] < 20]

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1)

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Cancer', 'Healthy']
colors = ['r', 'g']
ax.scatter(components2[controls2 == False, 0], components2[controls2 == False, 1], c = 'r', s = 10)
ax.scatter(components2[controls2 == True, 0], components2[controls2 == True, 1], c = 'g', s = 10)
ax.legend(targets)
ax.grid()

# %% [markdown]
# ### Logistic Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(norm_log_table, controls, test_size=0.33, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
plot_roc_curve(model, X_test, y_test)

# %% [markdown]
# ### XGBoost

# %%
model = XGBClassifier(use_label_encoder=False)
model.fit(X_train, y_train)
# Out:
# [15:45:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
plot_roc_curve(model, X_test, y_test)

# %% [markdown]
# ### Exporting data

# %%
lookup_table = data.gpls["GPL9040"].table

# %%
lookup_table = lookup_table.set_index("ID")

# %%
mirnas
# Out:
# 0          hsa-miR-890
# 2      hsa-miR-516a-5p
# 5       hsa-miR-139-3p
# 7          hsa-miR-453
# 8       hsa-miR-628-3p
#             ...
# 852     hsa-miR-138-1*
# 857        hsa-miR-765
# 858       hsa-miR-320a
# 859    hsa-miR-1224-5p
# 863        hsa-miR-940
# Name: ID_REF, Length: 389, dtype: object

# %%
sequences = lookup_table.loc[mirnas]["SEQUENCE"]

# %%
sequences = [s.upper() for s in sequences]

# %%
sequences[:10]
# Out:
# ['UACUUGGAAAGGCAUCAGUUG',
#  'UUCUCGAGGAAAGAAGCACUUUC',
#  'GGAGACGCGGCCCUGUUGGAGU',
#  'AGGUUGUCCGUGGUGAGUUCGCA',
#  'UCUAGUAAGAGUGGCAGUCGA',
#  'CAACAAAUCACAGUCUGCCAUA',
#  'UGAGCUAAAUGUGUGCUGGGA',
#  'GCCUGCUGGGGUGGAACCUGGU',
#  'ACGGGUUAGGCUCUUGGGAGCU',
#  'CCAAUAUUACUGUGCUGCUUUA']

# %%
norm_log_table.columns = sequences
norm_log_table = norm_log_table.loc[:,~norm_log_table.columns.duplicated()]
norm_log_table["cancer"] = sick

# %%
norm_log_table.head()
# Out:
#        UACUUGGAAAGGCAUCAGUUG  UUCUCGAGGAAAGAAGCACUUUC  GGAGACGCGGCCCUGUUGGAGU  \
# VALUE               1.230933                 0.956504                1.111901
# VALUE               0.558578                 0.561178                0.381927
# VALUE               0.350232                 0.747454                1.052135
# VALUE               0.895780                 0.846561                1.047780
# VALUE               0.607559                 0.574691                0.667237
#
#        AGGUUGUCCGUGGUGAGUUCGCA  UCUAGUAAGAGUGGCAGUCGA  CAACAAAUCACAGUCUGCCAUA  \
# VALUE                 0.643108               0.775135               -1.537241
# VALUE                 0.509823               0.405091               -1.537241
# VALUE                 0.600245               0.388387               -1.537241
# VALUE                 0.781441               0.419025               -0.227601
# VALUE                 0.441183               0.619864               -1.167959
#
#        UGAGCUAAAUGUGUGCUGGGA  GCCUGCUGGGGUGGAACCUGGU  ACGGGUUAGGCUCUUGGGAGCU  \
# VALUE               1.169659                1.276524                0.561996
# VALUE               0.863313                0.919936               -0.117545
# VALUE               0.387123                0.871127                0.095612
# VALUE               0.716767                0.820077                0.447182
# VALUE               0.574920                1.023657                0.062082
#
#        CCAAUAUUACUGUGCUGCUUUA  ...  UGAGGUAGUAGGUUGUAUAGUU  \
# VALUE               -1.275913  ...               -1.571419
# VALUE                0.233398  ...               -0.671390
# VALUE               -0.042011  ...               -1.603869
# VALUE                0.359831  ...               -1.508087
# VALUE                0.093594  ...               -1.477159
#
#        AGGCAGCGGGGUGUAGUGGAUA  CUAGACUGAAGCUCCUUGAGG  GACACGGGCGACAGCUGCGGCCC  \
# VALUE                0.911081              -0.550154                 0.408104
# VALUE                0.956033              -0.748782                -0.102563
# VALUE                1.005340              -0.170655                 0.310051
# VALUE                0.740256              -0.531753                 0.284822
# VALUE                0.840232              -0.170655                 0.225816
#
#        GCUACUUCACAACACCAGGGCC  UGGAGGAGAAGGAAGGUGAUG  AAAAGCUGGGUUGAGAGGGCGA  \
# VALUE                0.520154               1.296237               -0.347394
# VALUE                1.457285               0.570788               -0.894017
# VALUE                0.724976               1.216971               -0.695042
# VALUE                1.106109               1.316270               -1.251741
# VALUE                1.117896               1.296237               -0.573233
#
#        GUGAGGACUCGGGAGGUGG  AAGGCAGGGCCCCCGCUCCCC  cancer
# VALUE             1.465135               0.513281    True
# VALUE             1.113559               0.861160    True
# VALUE             1.129734               0.914912    True
# VALUE             1.172223               1.396316    True
# VALUE             1.338507               0.749306    True
#
# [5 rows x 387 columns]

# %%
norm_log_table.to_csv("../TransformedData/Keller2009.csv", index=False)
